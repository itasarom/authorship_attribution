# %%
import torch
import numpy as np

import ast
# %load_ext autoreload
# %autoreload 2

# %%
# import sys
# sys.version

# %%
import model
import train

# %%
import ast
import os

from collections import Counter, defaultdict

# %%
def fails(func):
    try:
        func()
        return False
    except:
        return True

# %%
def read_all(path = "../CodeStylometry/Corpus/temp/codejamfolder/py"):
    result = {}
    for handle in os.listdir(path):
        handle_path = os.path.join(path, handle)
        result_for_handle = defaultdict(str)
#         for contest in os.listdir(handle_path):
#             contest_path = os.path.join(handle_path, contest)
        for solution in os.listdir(handle_path):
                solution_path = os.path.join(handle_path, solution)
                with open(solution_path, "r") as f:
                    try:
                        result_for_handle[solution] = f.read()
                    except Exception as e:
                        print(solution_path)
                        print(e)
                    
        result[handle] = result_for_handle
        
    return result

# %%
def filter_by_count(data, min_count, max_count):
    result = {}
    for handle, result_for_handle in data.items():
        current = {}
        for problem, solution in result_for_handle.items():
            if not fails(lambda: ast.parse(solution)):
                current[problem.split(".")[0]] = solution


        if len(current) >= min_count and len(current) <= max_count:
            result[handle] = current
    
    return result

# %%
data = read_all()
# Out:
# ../CodeStylometry/Corpus/temp/codejamfolder/py/smartek0/p2463486.smartek0.py
# 'utf-8' codec can't decode byte 0xfc in position 111: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/RedApe0/p1481486.RedApe0.py
# 'utf-8' codec can't decode byte 0xee in position 1204: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/RedApe0/p1485488.RedApe0.py
# 'utf-8' codec can't decode byte 0xea in position 1289: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/RedApe0/p1080487.RedApe0.py
# 'utf-8' codec can't decode byte 0xf2 in position 1158: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/RedApe0/p1590487.RedApe0.py
# 'utf-8' codec can't decode byte 0xef in position 3183: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/RedApe0/p1480487.RedApe0.py
# 'utf-8' codec can't decode byte 0xe3 in position 1306: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/apinzonf0/p24481.apinzonf0.py
# 'utf-8' codec can't decode byte 0xf1 in position 63: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/apinzonf0/p24480.apinzonf0.py
# 'utf-8' codec can't decode byte 0xf1 in position 63: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/viz0/p24480.viz0.py
# 'utf-8' codec can't decode byte 0xc1 in position 46: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/viz0/p24486.viz0.py
# 'utf-8' codec can't decode byte 0xc1 in position 59: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/74th0/p1026487.74th0.py
# 'utf-8' codec can't decode byte 0xb2 in position 337: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/74th0/p1080487.74th0.py
# 'utf-8' codec can't decode byte 0xba in position 785: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/74th0/p1059486.74th0.py
# 'utf-8' codec can't decode byte 0xb2 in position 336: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/ipknHama0/p24481.ipknHama0.py
# 'utf-8' codec can't decode byte 0xb9 in position 77: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/imakaramegane0/p2453486.imakaramegane0.py
# 'utf-8' codec can't decode byte 0x89 in position 615: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/oonishi0/p2453486.oonishi0.py
# 'utf-8' codec can't decode byte 0x89 in position 314: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1026487.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 45: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1059486.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 45: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p992486.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 45: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1040487.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 54: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1062486.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 54: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1080487.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 45: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1048486.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 54: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/tc.0/p1058489.tc.0.py
# 'utf-8' codec can't decode byte 0xa9 in position 54: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/seiya0/p2449486.seiya0.py
# 'utf-8' codec can't decode byte 0x89 in position 209: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/seiya0/p2453486.seiya0.py
# 'utf-8' codec can't decode byte 0x89 in position 170: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Pena860/p5690574640250880.Pena860.py
# 'utf-8' codec can't decode byte 0xe4 in position 2319: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Lark0/p992486.Lark0.py
# 'utf-8' codec can't decode byte 0xf6 in position 2082: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Lark0/p1080487.Lark0.py
# 'utf-8' codec can't decode byte 0xe4 in position 1009: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Ikke0/p24481.Ikke0.py
# 'utf-8' codec can't decode byte 0xe9 in position 1452: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Taizo0/p5644738749267968.Taizo0.py
# 'utf-8' codec can't decode byte 0x82 in position 576: invalid start byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/vale.rho0/p1483485.vale.rho0.py
# 'utf-8' codec can't decode byte 0xe8 in position 62: invalid continuation byte
# ../CodeStylometry/Corpus/temp/codejamfolder/py/Pixinguinha0/p122101.Pixinguinha0.py
# 'utf-8' codec can't decode byte 0xe9 in position 634: invalid continuation byte

# %%
data = filter_by_count(data, 35, 70)

# %%
def filter_people(df, people):
    result = {}
    for handle, result_for_handle in df.items():
        if handle in people:
            result[handle] = result_for_handle
    
    return result

# %%
def filter_ast_size(df, mn=0, mx=500):
    result = {}
    for handle, result_for_handle in df.items():
        current_result = {}
        for problem, submission in result_for_handle.items():
            try:
                parsed = ast.parse(submission)
                length = len(list(ast.walk(parsed)))
                print(length)
                if length >= mn and length <= mx:
                    current_result[problem] = submission
            except:
                pass
            
        result[handle] = current_result
    
    return result

# %%
# data = filter_ast_size(data, mn=50, mx=4000)

# %%
print(sorted(data.keys()))
# Out:
# ['ali.assaf0', 'bigOnion0', 'd.operator0', 'damo.yu0', 'dennis.lissov0', 'mth0', 'pawko0']

# %%
batch_sampler = train.StratifiedBatcherPreprocessed(data, 64, 0.8)
# batch_sampler = train.NameBatcher(data, 64, train_problems, test_problems)

# %%
batch_sampler.classes
# Out:
# ['ali.assaf0',
#  'bigOnion0',
#  'd.operator0',
#  'damo.yu0',
#  'dennis.lissov0',
#  'mth0',
#  'pawko0']

# %%
batch_sampler.get_n_classes()
# Out:
# 7

# %%
np.unique(batch_sampler.y_train, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), array([37, 33, 28, 30, 34, 31, 32]))

# %%
np.unique(batch_sampler.y_test, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), array([10,  9,  7,  8,  9,  8,  8]))

# %%
cls = model.Model(batch_sampler.get_n_classes(), embedding_dims=100)

# %%
# trainer = train.Trainer(cls, torch.nn.CrossEntropyLoss(), torch.optim.SGD(cls.parameters(), lr=0.01, momentum=0.9))
trainer = train.Trainer(cls, torch.nn.CrossEntropyLoss(), torch.optim.Adam(cls.parameters()))

# %%
# %ls

# %%
torch.set_num_threads(1)

# %%
# cls.preprocessed = False

# %%
trainer.train(batch_sampler, {"n_epochs":800})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-aee8ffeabf85> in <module>()
# ----> 1 trainer.train(batch_sampler, {"n_epochs":800})
#
# ~/projects/authorship_attribution/train.py in train(self, batch_sampler, params)
#     380                 # print(y)
#     381                 self.optimizer.zero_grad()
# --> 382                 prediction = self.model(x)
#     383                 # print(prediction)
#     384                 # print(y)
#
# ~/torch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/projects/authorship_attribution/model.py in forward(self, input)
#     269     def forward(self, input):
#     270
# --> 271         embeddings = self.transform_batch(input)
#     272
#     273         # print(embeddings)
#
# ~/projects/authorship_attribution/model.py in transform_batch(self, input)
#     202         else:
#     203             for id, code in enumerate(input):
# --> 204                 result[id] = self.ast_encoder(ast.parse(code))
#     205
#     206         return result
#
# ~/torch/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/projects/authorship_attribution/model.py in forward(self, node)
#     174
#     175     def forward(self, node):
# --> 176         return self.visitor.visit(node)
#     177
#     178
#
# ~/projects/authorship_attribution/model.py in visit(self, node)
#      47
#      48     def visit(self, node):
# ---> 49         return self.embed_node(node)
#      50
#      51     def node_to_index(self, node):
#
# ~/projects/authorship_attribution/model.py in embed_node(self, node)
#      66         if len(list(ast.iter_child_nodes(node))):
#      67             embeddings = [node_embedding]
# ---> 68             embeddings += self.embed_subtree(node)
#      69             # result = self.embedding_network(torch.cat((node_embedding, subtree_embedding), -1))
#      70             # c_0 = torch.zeros(1, self.embedding_dim)
#
# ~/projects/authorship_attribution/model.py in embed_subtree(self, node)
#     100         for child in ast.iter_child_nodes(node):
#     101             # print(child)
# --> 102             child_embedding = self.embed_node(child).view(1, -1)
#     103             children_embeddings.append(child_embedding)
#     104             # (c_0, h_0) = self.subtree_network(child_embedding, (c_0, h_0))
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def build_confusion_matrix(predicted_probs, true):
    n_labels = predicted_probs.shape[1]
#     assert true_y.shape == predicted_probs.shape
    result = np.zeros(shape=(n_labels, n_labels))
    
    pred = predicted_probs.argmax(axis=1)
    
#     print(pred)
#     print(true)
#     print(len(true))
    
    accuracy = np.count_nonzero(pred == true.ravel())/len(true)
    print("Accuracy = ", accuracy)
#     true = true_y.argmax(axis=1)
    
    for pred_cls in range(n_labels):
        for true_cls in range(n_labels):
            result[true_cls, pred_cls] = np.count_nonzero(true[pred == pred_cls] == true_cls)
    norm = result.sum(axis=1)
    norm = np.maximum(norm, 1)
#     result /= norm[:, None]
    return result

def plot_confusion_matrix(confusion_matrix):
    fig = plt.figure( figsize=(20, 20))
    plt.xlabel("True classes")
    plt.ylabel("Predicted classes")
#     sns.heatmap(confusion_matrix, annot=True, vmin=0.0, vmax=1.0, cmap="YlGnBu")
    sns.heatmap(confusion_matrix, annot=True, vmin=0.0, cmap="YlGnBu")

# %%
import gc
gc.collect()
# Out:
# 3250

# %%
cls.eval()
x, y = batch_sampler.x_train, batch_sampler.y_train
pred = torch.nn.functional.softmax(cls.forward(x), dim=1)

# %%
plot_confusion_matrix(build_confusion_matrix(pred.detach().numpy(), y.reshape(-1, 1)))
# Out:
# Accuracy =  1.0

# %%
#cls.eval()
x, y = batch_sampler.x_test, batch_sampler.y_test
pred = torch.nn.functional.softmax(cls.forward(x), dim=1)

# %%
plot_confusion_matrix(build_confusion_matrix(pred.detach().numpy(), y.reshape(-1, 1)))
# Out:
# Accuracy =  0.9491525423728814

# %%
from sklearn.decomposition import PCA
import matplotlib.cm as cm
n_classes = batch_sampler.get_n_classes()
# colors = {0:'r', 1:'g', 2:'b', 3:'c', 4:'y
colors = {i:c for i, c in enumerate(cm.rainbow(np.linspace(0, 1, n_classes)))}
pca = PCA(n_components=2)
x_transformed = cls.transform_batch(batch_sampler.x_train)
x_test_transformed = cls.transform_batch(batch_sampler.x_test)
pca.fit(x_transformed.detach())
def plot_pca(x, y, alpha=1.0):
    plt.figure(figsize=(20, 20))
    plt.scatter(x[:, 0], x[:, 1], color=list(map(colors.get, y)), alpha=alpha)
    plt.show()

# %%
plt.figure(figsize=(20, 20))
plot_pca(pca.transform(x_transformed.detach()), batch_sampler.y_train, alpha=1.0)
plot_pca(pca.transform(x_test_transformed.detach()), batch_sampler.y_test, alpha=1.0)
# plt.show()
