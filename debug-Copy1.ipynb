# %%
import torch
import numpy as np

import ast
# %load_ext autoreload
# %autoreload 2

# %%
import model
import train

# %%
import ast

# %%
def fails(func):
    try:
        func()
        return False
    except:
        return True

# %%
data = train.read_all()
data = {handle:result_for_handle for handle, result_for_handle in data.items() if len(result_for_handle) >= 65 and len(result_for_handle) <= 70}

# %%
common_problems = ['935:A [Fafa and his Company].py',
 '935:B [Fafa and the Gates].py',
 '935:C [Fifa and Fafa].py',
 '937:A [Olympiad].py',
 '938:A [Word Correction].py',
 '938:B [Run For Your Prize].py',
 '950:A [Left-handers, Right-handers and Ambidexters].py']


common_problems = ['950:A [Left-handers, Right-handers and Ambidexters].py',
 '931:A [Friends Meeting].py',
 '935:A [Fafa and his Company].py',
 '935:B [Fafa and the Gates].py',
 '937:A [Olympiad].py',
 '932:A [Palindromic Supersequence].py',
 '938:A [Word Correction].py',
 '950:B [Intercepted Message].py',
 '931:B [World Cup].py',
 '935:C [Fifa and Fafa].py',
 '946:C [String Transformation].py',
 '934:B [A Prosperous Lot].py',
 '939:A [Love Triangle].py',
 '934:A [A Compatible Pair].py',
 '940:B [Our Tanya is Crying Out Loud].py']

common_problems = [
    '935:B [Fafa and the Gates].py',
 '935:C [Fifa and Fafa].py',
 '950:B [Intercepted Message].py',
 '935:A [Fafa and his Company].py',
 '938:A [Word Correction].py',
 '950:A [Left-handers, Right-handers and Ambidexters].py',
 '938:B [Run For Your Prize].py',
 '937:A [Olympiad].py',
 '940:B [Our Tanya is Crying Out Loud].py',
 '938:C [Constructing Tests].py',
 '940:A [Points on the line].py',
 '937:C [Save Energy!].py',
 '934:B [A Prosperous Lot].py',
 '931:B [World Cup].py',
 '939:A [Love Triangle].py']


common_problems = ['946:A [Partition].py',
 '935:B [Fafa and the Gates].py',
 '935:C [Fifa and Fafa].py',
 '935:A [Fafa and his Company].py',
 '940:B [Our Tanya is Crying Out Loud].py',
 '929:A [Прокат велосипедов].py',
 '940:A [Points on the line].py',
 '950:B [Intercepted Message].py',
 '938:B [Run For Your Prize].py',
 '946:C [String Transformation].py',
 '946:B [Weird Subtraction Process].py',
 '934:B [A Prosperous Lot].py',
 '931:B [World Cup].py',
 '939:A [Love Triangle].py',
 '931:C [Laboratory Work].py',
 '934:A [A Compatible Pair].py',
 '937:B [Vile Grasshoppers].py',
 '932:A [Palindromic Supersequence].py',
 '938:A [Word Correction].py',
 '950:A [Left-handers, Right-handers and Ambidexters].py',
 '939:B [Hamster Farm].py',
 '931:A [Friends Meeting].py',
 '937:A [Olympiad].py']

common_problems = ['950:A [Left-handers, Right-handers and Ambidexters].py',
 '937:A [Olympiad].py',
 '935:A [Fafa and his Company].py',
 '935:B [Fafa and the Gates].py',
 '931:A [Friends Meeting].py',
 '946:A [Partition].py',
 '938:A [Word Correction].py',
 '950:B [Intercepted Message].py',
 '946:C [String Transformation].py',
 '932:A [Palindromic Supersequence].py',
 '931:B [World Cup].py',
 '939:A [Love Triangle].py',
 '946:B [Weird Subtraction Process].py',
 '939:B [Hamster Farm].py',
 '935:C [Fifa and Fafa].py',
 '934:B [A Prosperous Lot].py',
 '940:A [Points on the line].py',
 '937:B [Vile Grasshoppers].py',
 '940:B [Our Tanya is Crying Out Loud].py',
 '938:B [Run For Your Prize].py',
 '934:A [A Compatible Pair].py',
 '931:C [Laboratory Work].py',
 '937:C [Save Energy!].py',
 '940:C [Phone Numbers].py',
 '948:A [Protect Sheep].py',
 '931:D [Peculiar apple-tree].py',
 '939:C [Convenient For Everybody].py',
 '935:D [Fafa and Ancient Alphabet].py',
 '940:D [Alena And The Heater].py',
 '938:C [Constructing Tests].py',
 '950:C [Zebras].py',
 '934:D [A Determined Cleanup].py',
 '929:B [Места в самолёте].py',
 '929:A [Прокат велосипедов].py',
 '944:A [World Cup].py',
 '937:E [Lock Puzzle].py',
 '933:A [A Twisty Movement].py',
 '944:B [Laboratory Work].py',
 '929:C [Красивая команда].py',
 '934:C [A Twisty Movement].py',
 '939:D [Love Rescue].py',
 '948:B [Primal Sport].py',
 '937:D [Sleepy Game].py']


common_problems = [
    '934:A [A Compatible Pair].py',
 '935:A [Fafa and his Company].py',
 '935:C [Fifa and Fafa].py',
 '946:A [Partition].py',
 '946:C [String Transformation].py',
 '977:B [Two-gram].py',
 '978:A [Remove Duplicates].py',
 '980:A [Links and Pearls].py',
 '981:A [Antipalindrome].py',
 '985:B [Switches and Lamps].py'
]

# %%
# train_size = 8
# train_problems = common_problems[:train_size]
# test_problems = common_problems[train_size:]

# %%
train_problems
# Out:
# ['934:A [A Compatible Pair].py',
#  '935:A [Fafa and his Company].py',
#  '935:C [Fifa and Fafa].py',
#  '946:A [Partition].py',
#  '946:C [String Transformation].py',
#  '977:B [Two-gram].py',
#  '978:A [Remove Duplicates].py',
#  '980:A [Links and Pearls].py']

# %%
# for handle, result_for_handle in data.items():
#     current = {}
#     for problem, solution in result_for_handle.items():
#         if problem in common_problems:
#             if not fails(lambda: ast.parse(solution)):
#                 current[problem] = solution
    
#     data[handle] = current

# %%
# for handle, result_for_handle in data.items():
#     current = {}
#     for problem, solution in result_for_handle.items():
#             if not fails(lambda: ast.parse(solution)):
#                 l = list(ast.walk(ast.parse(solution)))
#                 if len(l) >= 120:
#                     current[problem] = solution
    
#     data[handle] = current

# %%
# test.keys()

# %%
# data

# %%
# for node in ast.walk(parsed):
#     print(node)

# %%
# train_problems

# %%
batch_sampler = train.StratifiedBatcher(data, 64, 0.75)
# batch_sampler = train.NameBatcher(data, 64, train_problems, test_problems)

# %%
batch_sampler.get_n_classes()
# Out:
# 3

# %%
np.unique(batch_sampler.y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([49, 51, 49]))

# %%
np.unique(batch_sampler.y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([17, 18, 17]))

# %%
cls = model.Model(batch_sampler.get_n_classes(), embedding_dims=100)

# %%
# trainer = train.Trainer(cls, torch.nn.CrossEntropyLoss(), torch.optim.SGD(cls.parameters(), lr=0.01, momentum=0.9))
trainer = train.Trainer(cls, torch.nn.CrossEntropyLoss(), torch.optim.Adam(cls.parameters()))

# %%
trainer.train(batch_sampler, {"n_epochs":400})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-cbbcac27f122> in <module>()
# ----> 1 trainer.train(batch_sampler, {"n_epochs":400})
#
# /media/itasarom/7158f0d7-af1d-45d4-855f-86204aed5a8b/Projects/kropotov/implementation/train.py in train(self, batch_sampler, params)
#     250                 loss = self.loss_object(prediction, y)
#     251                 regularized_loss = loss + 0.001 * self.model.regularizer()
# --> 252                 regularized_loss.backward()
#     253                 print(regularized_loss)
#     254
#
# ~/.local/lib/python3.5/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/.local/lib/python3.5/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
ev = cls.ast_encoder

# %%
code = """
if x:
    x = 10
    x = 10
else:
    pass
"""

# %%
torch.norm(ev.subtree_network.weight_hh_l0)
# Out:
# tensor(13.1229)

# %%
ev.embedding_layer.weight
# Out:
# Parameter containing:
# tensor([[ 1.3429, -1.0953, -0.4183,  ..., -1.2672,  1.1768,  0.1006],
#         [ 0.9697, -0.7005,  0.1561,  ...,  1.1039, -0.8168,  0.2357],
#         [-1.2359, -0.5653, -0.9483,  ..., -0.7794,  0.5790,  0.4103],
#         ...,
#         [-0.1623, -1.4673,  0.3618,  ...,  3.3089, -0.7877,  0.3160],
#         [-1.1842, -0.8417, -0.2759,  ..., -1.4875, -0.2356, -1.2350],
#         [-0.7830, -0.9317,  0.0144,  ..., -0.0687,  1.7918,  0.1393]])

# %%
ev(ast.parse(code))
# Out:
# tensor([ 0.0866,  0.3544,  0.6758, -0.0354,  0.0449,  0.5990,  0.4787,
#          0.5473,  0.5024,  0.7971,  0.5783,  0.6559,  0.2166,  0.0759,
#          0.4948,  0.4249,  0.0152,  0.5892,  0.5610,  0.4877,  0.4179,
#          0.2622,  0.0520,  0.2292,  0.6899,  0.5455,  0.5411,  0.1615,
#          0.1248,  0.3779,  0.5785,  0.3322,  0.5438,  0.5331,  0.5187,
#          0.5760,  0.6697,  0.4433,  0.7518,  0.4926,  0.5821,  0.2195,
#          0.4930,  0.4435,  0.6380,  0.4874,  0.6711,  0.4454,  0.4917,
#          0.4450,  0.4877,  0.4599, -0.1026,  0.4055, -0.4335,  0.6378,
#          0.5217,  0.0854, -0.0446,  0.5021,  0.6789,  0.4519,  0.3216,
#          0.0223,  0.1562,  0.1119,  0.3657,  0.3495, -0.2160,  0.4307,
#          0.4145,  0.4889,  0.6214,  0.5483,  0.4473, -0.1107,  0.3891,
#          0.5599,  0.5882,  0.0313,  0.4189,  0.1597,  0.4748,  0.5169,
#          0.5339,  0.5362,  0.7563,  0.4195,  0.5484,  0.2441,  0.7455,
#          0.0609,  0.4753,  0.5869,  0.5423,  0.4328,  0.1372,  0.5812,
#          0.6394,  0.4697])

# %%
code = """
if x:
    x = 10
    x = 10
    if x:
        x = 10
        x = 10
        if x:
            x = 10
            x = 10
        else:
            pass
    else:
        pass
else:
    pass
"""

# %%
ev(ast.parse(code))
# Out:
# tensor([ 0.0703,  0.3640,  0.6659, -0.0339,  0.1027,  0.5689,  0.5354,
#          0.5641,  0.5032,  0.8051,  0.6059,  0.6642,  0.2298,  0.1060,
#          0.4699,  0.3998,  0.0397,  0.5817,  0.5655,  0.5156,  0.4312,
#          0.2690,  0.0575,  0.1910,  0.6886,  0.5477,  0.5171,  0.1626,
#          0.1394,  0.3455,  0.5909,  0.3429,  0.5581,  0.5465,  0.5125,
#          0.5549,  0.6483,  0.4495,  0.7460,  0.4952,  0.6288,  0.2405,
#          0.5241,  0.4487,  0.6238,  0.4850,  0.6866,  0.4582,  0.6277,
#          0.4176,  0.4713,  0.4066, -0.2125,  0.4231, -0.4854,  0.5858,
#          0.5321,  0.1029, -0.0520,  0.4731,  0.6724,  0.4692,  0.3585,
#          0.0826,  0.1766,  0.1202,  0.3673,  0.3436, -0.2429,  0.4308,
#          0.4110,  0.4808,  0.6059,  0.5591,  0.4592, -0.0921,  0.4141,
#          0.5536,  0.6060, -0.0048,  0.3732,  0.1575,  0.4949,  0.5349,
#          0.5258,  0.5156,  0.7614,  0.4159,  0.5220,  0.1508,  0.7380,
#          0.1431,  0.4589,  0.5941,  0.5287,  0.4308,  0.1340,  0.6234,
#          0.6405,  0.4813])

# %%
trainer.validation_metrics['accuracy']
# Out:
# [0.34615384615384615,
#  0.3269230769230769,
#  0.38461538461538464,
#  0.38461538461538464,
#  0.46153846153846156,
#  0.5,
#  0.5192307692307693,
#  0.5384615384615384,
#  0.5576923076923077,
#  0.5769230769230769,
#  0.5961538461538461,
#  0.46153846153846156,
#  0.5192307692307693,
#  0.5769230769230769,
#  0.5576923076923077]

# %%
trainer.train_metrics['accuracy']
# Out:
# [0.348993288590604,
#  0.3422818791946309,
#  0.4228187919463087,
#  0.5234899328859061,
#  0.6174496644295302,
#  0.6577181208053692,
#  0.6644295302013423,
#  0.6845637583892618,
#  0.738255033557047,
#  0.738255033557047,
#  0.7718120805369127,
#  0.7516778523489933,
#  0.8187919463087249,
#  0.8389261744966443,
#  0.825503355704698]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def build_confusion_matrix(predicted_probs, true):
    n_labels = predicted_probs.shape[1]
#     assert true_y.shape == predicted_probs.shape
    result = np.zeros(shape=(n_labels, n_labels))
    
    pred = predicted_probs.argmax(axis=1)
#     true = true_y.argmax(axis=1)
    
    for pred_cls in range(n_labels):
        for true_cls in range(n_labels):
            result[true_cls, pred_cls] = np.count_nonzero(true[pred == pred_cls] == true_cls)
    norm = result.sum(axis=1)
    norm = np.maximum(norm, 1)
#     result /= norm[:, None]
    return result

def plot_confusion_matrix(confusion_matrix):
    fig = plt.figure( figsize=(20, 20))
    plt.xlabel("True classes")
    plt.ylabel("Predicted classes")
#     sns.heatmap(confusion_matrix, annot=True, vmin=0.0, vmax=1.0, cmap="YlGnBu")
    sns.heatmap(confusion_matrix, annot=True, vmin=0.0, cmap="YlGnBu")

# %%
import gc
gc.collect()
# Out:
# 17196

# %%
x, y = batch_sampler.x_train, batch_sampler.y_train
pred = torch.nn.functional.softmax(cls.forward(x), dim=1)

# %%
plot_confusion_matrix(build_confusion_matrix(pred.detach().numpy(), y.reshape(-1, 1)))

# %%
x, y = batch_sampler.x_test, batch_sampler.y_test
pred = torch.nn.functional.softmax(cls.forward(x), dim=1)

# %%
plot_confusion_matrix(build_confusion_matrix(pred.detach().numpy(), y.reshape(-1, 1)))

# %%
for code in batch_sampler.x_train:
    print(code)
    print("#######################################\n#############")
# Out:
# n = int(input())
# cl = list(map(int, input().split()))
# s = input()
# dic = {}
# for x in range(n):
#   dic.update({cl[x]:x+1})
#
# cl = sorted(cl)
# pl = []
# res = ''
# pos1=0
# for c in s:
#   if c=='0':
#     pl.append(cl[pos1])
#     res+=str(dic[cl[pos1]])+' '
#     pos1+=1
#   if c=='1':
#     mx = pl[-1]
#     res+=str(dic[mx])+ ' '
#     pl.pop(-1)
#
# print(res)
# #######################################
# #############
# n,m,k=map(int,input().split())
# k+=1
# if k<=n:
#     print(k,1)
# else:
#     k-=n
#     k-=1
#     y=n-k//(m-1)
#     if y%2==0:
#         x=k%(m-1)+2
#     else:
#         x=m-k%(m-1)
#     print(y,x)
#
#
# #######################################
# #############
# n=int(input())
# n+=1
# if n==1:
#     print(0)
#     exit()
# if n%2:
#     print(n)
# else:
#     print(n//2)
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# s = (sum(lst) + 1) // 2
#
# array = [0]
# for x in range(n):
#     p = array[-1] + lst[x]
#     array.append(p)
#     if p >= s:
#         break
#
# print(x + 1)
# #######################################
# #############
# n = int(input())
# s = input()
# '''
# d = {}
# def xxx(l, r):
#     if (l, r) in d:
#         return d[l, r]
#     if r - l == 0:
#         d[l, r] = 0
#         return 0
#     if r - l == 1:
#         if s[l] == 1:
#             d[l, r] = -1
#             return -1
#         d[l, r] = 1
#         return 1
#     if s[l] != s[r - 1]:
#         d[l, r] = xxx(l + 1, r - 1)
#         return xxx(l + 1, r - 1)
#     if s[l] == '1' and s[r - 1] == '1':
#         d[l, r] = xxx(l + 1, r - 1) - 2
#         return xxx(l + 1, r - 1) - 2
#     d[l, r] = xxx(l + 1, r - 1) + 2
#     return xxx(l + 1, r - 1) + 2
#
#
# lst = [0]
# for x in range(0, len(s)):
#     for y in range(x + 1, len(s) + 1):
#         if xxx(x, y) == 0:
#             lst.append(y - x)
# print(max(lst))
# '''
# d = {0: 0}
# acc = 0
# lst = [0]
# for x in range(len(s)):
#     if s[x] == '0':
#         a = -1
#     else:
#         a = 1
#     acc += a
#     if not acc in d:
#         d[acc] = x + 1
#     else:
#         lst.append(x - d[acc] + 1)
# print(max(lst))
#
# #######################################
# #############
# mx = 0
# s = list(map(int, input().split()))
# for i in range(14):
#  if s[i]>0:
#   res = 0
#   sw = list(s)
#   x = sw[i]
#   sw[i]=0
#   if x<14-i-1:
#    for j in range(i+1, i+x+1):
#     sw[j]+=1
#   else:
#    x-=14-i-1
#    for j in range(i+1, 14):
#     sw[j]+=1
#    t = x//14
#    ost = x%14
#    for j in range(14):
#     if j<ost:
#      sw[j]+=t+1
#     else:
#      sw[j]+=t
#   for x in sw:
#    if x%2==0:
#     res+=x
#   if res>=mx:
#    mx = res
#
# print(mx)
# #######################################
# #############
# n,w=map(int,input().split())
# Amin=0
# Amax=0
# s=0
# for i in list(map(int,input().split())):
#     s+=i
#     if s>Amax:
#         Amax=s
#     if s<Amin:
#         Amin=s
# ans=w-Amax+Amin+1
# if ans<0:
#     print(0)
# else:
#     print(ans)
#
# #######################################
# #############
# b=list(map(int,input().split()))
# pans=0
# for i in range(14):
#     a=b.copy()
#     if a[i]==0:
#         continue
#     k=a[i]
#     a[i]=0
#     for j in range(i+1,14):
#         k-=1
#         a[j]+=1
#     for j in range(14):
#         a[j]+=k//14
#     k%=14
#     for j in range(k):
#         a[j]+=1
#     ans=0
#     for j in range(14):
#         if a[j]%2==0:
#             ans+=a[j]
#     if ans>pans:
#         pans=ans
# print(pans)
#
#
#
# #######################################
# #############
# s = input()
# string = s.split('_')
#
# k = 0
# lst = ['Danil', 'Olya', 'Slava', 'Ann', 'Nikita']
# if len(string) != 1:
#     for x in string:
#         if x in lst:
#             k += 1
#     if k == 1:
#         print("YES")
#     else:
#         print("NO")
# else:
#     for x in lst:
#         if s.count(x):
#             k += s.count(x)
#     if k == 1:
#         print("YES")
#     else:
#         print("NO")
#
# #######################################
# #############
# s = input().split()
# l, r, a = int(s[0]), int(s[1]), int(s[2])
# x = min(l, r)
# y = max(l, r)
# while(a!=0 and x!=y):
#     x+=1
#     a-=1
#
# print(min(x, y)*2 + a//2*2)
# #######################################
# #############
# n=int(input())
# a=list(map(int,input().split()))
# for i in a:
#     q=i+0
#     for j in range(n-1):
#         if i*2 in a:
#             i*=2
#         elif i%3==0 and i//3 in a:
#             i//=3
#         else:
#             break
#     else:
#         print(q,end=' ')
#         for j in range(n-1):
#             if q*2 in a:
#                 q*=2
#                 print(q,end=' ')
#             elif q//3 in a:
#                 q//=3
#                 print(q,end=' ')
#         break
# #######################################
# #############
# n=int(input())
# s=input()
# x=0
# y=0
# ans=0
# for i in range(n-1):
#     if s[i]=='U':
#         y+=1
#     else:
#         x+=1
#     if y==x and s[i+1]==s[i]:
#         ans+=1
# print(ans)
#
# #######################################
# #############
# s=input()
# ans=s+''
# l=len(s)
# a='abcdefghijklmnopqrstuvwxyz'
# i=0
# for j in range(26):
#     while s[i]>a[j]:
#         i+=1
#         if i==l:
#             print(-1)
#             exit()
#     ans=ans[:i]+a[j]+ans[i+1:]
#     i+=1
#     if j!=25 and i==l:
#         print(-1)
#         exit()
# print(ans)
#
# #######################################
# #############
# n=int(input())
# k=int(input())
# a=int(input())
# b=int(input())
# ans=0
# if k==1:
#     print((n-1)*a)
#     exit()
# else:
#     while n>1:
#         ans+=(n%k)*a
#         n-=n%k
#         if b>(n-n//k)*a:
#             print((n-1)*a+ans)
#             exit()
#         else:
#             n//=k
#             ans+=b
# print(ans)
#
#
#
#
# #######################################
# #############
# k = int(input())
#
# if k > 36:
#     print(-1)
# else:
#     if k % 2 == 0:
#         print('8' * (k // 2))
#     else:
#         print('8' * (k // 2) + '9')
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# n,m=read()
# x=read()
# y=read()
# i=0
# j=0
# s1=0
# s2=0
# ans=0
# q=True
# while not (i==n and j==m):
#     s1+=x[i]
#     i+=1
#     while s1!=s2:
#         if s1<s2:
#             s1+=x[i]
#             i+=1
#         else:
#             s2+=y[j]
#             j+=1
#     ans+=1
#     s1=0
#     s2=0
# print(ans)
#
#
# #######################################
# #############
# n,a,b=map(int,input().split())
# k=a+b
# a,b=min(a,b),max(a,b)
# s=input()
# q=True
# for i in s:
#     if i=='.':
#         if q:
#             if b!=0:
#                 b-=1
#             q=False
#         else:
#             if a!=0:
#                 a-=1
#             q=True
#         if a == b == 0:
#             break
#     else:
#         q=True if b>a else False
#
# print(k-a-b)
#
#
# #######################################
# #############
# (n, m) = map(int, input().split())
#
# lst = []
# for x in range(n):
#     lst.append(input())
#
# array_num = list(map(int, input()))
# def xxx(up, down, left, right, x, y, i):
#     if lst[x][y] =='E':
#         return True
#     if i == len(array_num):
#         return False
#     if array_num[i] == up:
#         if x - 1 >= 0 and lst[x - 1][y] != '#':
#             return xxx(up, down, left, right, x - 1, y, i + 1)
#     if array_num[i] == down:
#         if x + 1 <= n - 1 and lst[x + 1][y] != '#':
#             return xxx(up, down, left, right, x + 1, y, i + 1)
#     if array_num[i] == left:
#         if y - 1 >= 0 and lst[x][y - 1] != '#':
#             return xxx(up, down, left, right, x, y - 1, i + 1)
#     if array_num[i] == right:
#         if y + 1 <= m - 1 and lst[x][y + 1] != '#':
#             return xxx(up, down, left, right, x, y + 1, i + 1)
# for x in range(n):
#     for y in range(m):
#         if lst[x][y] == 'S':
#             (i, j) = (x, y)
#             break
# k = 0
# if xxx(1, 2, 3, 0, i, j, 0):
#     k += 1
# if xxx(1, 2, 0, 3, i, j, 0):
#     k += 1
# if xxx(1, 3, 2, 0, i, j, 0):
#     k += 1
# if xxx(1, 3, 0, 2, i, j, 0):
#     k += 1
# if xxx(1, 0, 2, 3, i, j, 0):
#     k += 1
# if xxx(1, 0, 3, 2, i, j, 0):
#     k += 1
#
# if xxx(2, 1, 3, 0, i, j, 0):
#     k += 1
# if xxx(2, 1, 0, 3, i, j, 0):
#     k += 1
# if xxx(2, 3, 1, 0, i, j, 0):
#     k += 1
# if xxx(2, 3, 0, 1, i, j, 0):
#     k += 1
# if xxx(2, 0, 1, 3, i, j, 0):
#     k += 1
# if xxx(2, 0, 3, 1, i, j, 0):
#     k += 1
#
# if xxx(3, 1, 2, 0, i, j, 0):
#     k += 1
# if xxx(3, 1, 0, 2, i, j, 0):
#     k += 1
# if xxx(3, 2, 1, 0, i, j, 0):
#     k += 1
# if xxx(3, 2, 0, 1, i, j, 0):
#     k += 1
# if xxx(3, 0, 1, 2, i, j, 0):
#     k += 1
# if xxx(3, 0, 2, 1, i, j, 0):
#     k += 1
#
# if xxx(0, 1, 2, 3, i, j, 0):
#     k += 1
# if xxx(0, 1, 3, 2, i, j, 0):
#     k += 1
# if xxx(0, 2, 1, 3, i, j, 0):
#     k += 1
# if xxx(0, 2, 3, 1, i, j, 0):
#     k += 1
# if xxx(0, 3, 1, 2, i, j, 0):
#     k += 1
# if xxx(0, 3, 2, 1, i, j, 0):
#     k += 1
# print(k)
#
# #######################################
# #############
# n=int(input())
# s=input()
# i=0
# ans=0
# while True:
#     j=0
#     while s[i]=='x':
#         i+=1
#         j+=1
#         if i==n:
#             break
#     ans+=max(0,j-2)
#     i+=1
#     if i>=n:
#         break
# print(ans)
#
#
# #######################################
# #############
# n = int(input())
# s = input()
# count = 0
# i = 0
# st = True
# while(i<n-1):
#   if s[i]!=s[i+1]:
#     count+=1
#     if i==n-2:
#       st = False
#     i+=2
#   else:
#     count+=1
#     i+=1
#
# if st:
#   count+=1
#
# print(count)
# #######################################
# #############
#
# #######################################
# #############
# cl = list(map(int, input().split()))
# n, m = cl[0], cl[1]
# cl = ['']*m
# dic = {}
# for i in range(n):
#     s = input()
#     for j in range(m):
#         cl[j]+=s[j]
#         if s[j]=='1':
#             dic[j]=i
#
# st = set()
# for x in range(m):
#     if cl[x].count('1')==1:
#         st.add(dic[x])
#
# if len(st)==n:
#     print('NO')
# else:
#     print('YES')
# #######################################
# #############
# n=int(input())
# a=list(map(int,input().split()))
# b=list(sorted(a,reverse=True))
# c=[]
# for i in range(n):
#     for j in range(n-i-1):
#         if abs(a[j]-a[j+1])>=2:
#             print('NO')
#             exit()
#     q=max(a)
#     qi=a.index(q)
#     c.append(q)
#     for j in range(i):
#         if abs(c[j]-c[j+1])>=2:
#             print('NO')
#             exit()
#     del a[qi]
# print('YES')
#
#
# #######################################
# #############
# s = input()
# n = len(s)
# if n<3:
#     print('No')
# else:
#     for i in range(n-2):
#         if s[i]!=s[i+1] and s[i]!=s[i+2] and s[i+2]!=s[i+1] and s[i]!='.' and s[i+1]!='.' and s[i+2]!='.':
#             print('Yes')
#             exit()
#     print('No')
# #######################################
# #############
# n,k=map(int,input().split())
# for i in range(k):
#     if n%10:
#         n-=1
#     else:
#         n//=10
# print(n)
#
# #######################################
# #############
# s = list(map(int, input().split()))
# k, n, s, p = s[0], s[1], s[2], s[3]
# a = n//s
# if s*a!=n:
#   a+=1
#
# t = a*k//p
# if p*t!=a*k:
#   t+=1
#
# print(t)
# #######################################
# #############
# n = int(input())
# s = input().split()
# cl = []
# for i in range(n):
#     if s[i] not in cl and s[i]!='0':
#         cl.append(s[i])
#
# print(len(cl))
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# n=int(input())
# ans=0
# for i in range(1,n):
#     if (n-i)%i==0:
#         ans+=1
# print(ans)
#
# #######################################
# #############
# n = int(input())
# st1 = True
# st2 = True
# k1 = 0
# k2 = 0
# k=1
# while((st1 or st2) and k<=n):
#   s = input()
#   a = int(s.split()[0])
#   if a<0 and st1!=False:
#     if k1==0:
#       k1+=1
#     else:
#       st1 = False
#
#   if a>0 and st2!=False:
#     if k2==0:
#       k2+=1
#     else:
#       st2 = False
#   if k1>1 and k2>1:
#     st1 = False
#     st2 = False
#     break
#
#   k+=1
#
#
# if st1 or st2:
#   print('Yes')
# else:
#   print('No')
# #######################################
# #############
# s=input().split()
# n = int(s[0])
# m=int(s[1])
# dic = {}
# for x in range(n):
#   s = input().split()
#   dic.update({s[1]:s[0]})
# for y in range(m):
#   s = input()
#   s1 = s.split()
#   print(s+' #'+dic[s1[1][:-1]])
# #######################################
# #############
# (n, k) = map(int, input().split())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# i = 0
# for x in lst:
#     if k % x == 0:
#         i = max(i, x)
#
# print(k // i)
#
# #######################################
# #############
# n = int(input())
#
# if n % 2 == 1:
#     print("Ehab")
# else:
#     print("Mahmoud")
#
# #######################################
# #############
# s = input().split()
# n, m = int(s[0]), int(s[1])
# cl = list(map(int, input().split()))
# norm = []
# block = []
# for x in range(n):
#     if cl[x] not in block:
#         block.append(cl[x])
#         norm.append(x+1)
#
# k = len(norm)
# if m>k:
#     print('NO')
# else:
#     print('YES')
#     print(*norm[:m])
# #######################################
# #############
# s = input().split()
# n, p = int(s[0]), int(s[1])
# cl = list(map(int, input().split()))
# mx = 0
# sm = sum(cl)
# qs = cl[0]
# for i in range(1, n):
#   y = qs%p + (sm-qs)%p
#   if y>mx:
#     mx = y
#   qs+=cl[i]
#
# print(mx)
# #######################################
# #############
# import math
# def read():
#     return list(map(int,input().split()))
# k,n,s,p=read()
# print(math.ceil(math.ceil(n/s)*k/p))
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# n,m=read()
# a=[]
# for i in range(n):
#     a.append(input())
# ans=[0]*n
# for i in range(m):
#     ind=-1
#     for j in range(n):
#         if a[j][i]=='1':
#             if ind!=-1:
#                 ind=-1
#                 break
#             ind=j
#     if ind!=-1:
#         ans[ind]=1
# if 0 in ans:
#     print('YES')
# else:
#     print('NO')
#
#
#
#
#
#
# #######################################
# #############
# t = int(input())
#
# for x in range(t):
#     (n, k) = map(int, input().split())
#     lst = []
#     for y in input().split():
#         lst.append(int(y))
#     l = max(lst[0], n + 1 - lst[-1])
#     for y in range(1, len(lst)):
#         l = max(l, (lst[y] - lst[y - 1] + 2) // 2)
#     print(l)
#
# #######################################
# #############
# n,m=map(int,input().split())
# a=list(map(int,input().split()))
# b=list(map(int,input().split()))
# m=-100000000000000000000
# for i in b:
#     for j in a:
#         if j*i>m:
#             m=j*i
#             k=j
# a.remove(k)
# m=-100000000000000000000
# for i in b:
#     for j in a:
#         if j*i>m:
#             m=j*i
# print(m)
#
#
# #######################################
# #############
# n = int(input())
# a = int(input())
# b = int(input())
# c = int(input())
#
# k = 1
#
# ab = min(a, b)
# bc = min(b, c)
# ca = min(c, a)
#
# acc = 0
# while n > 1:
#     if k == 1:
#         acc += ab
#         if ab == a:
#             k = 2
#         else:
#             k = 3
#     elif k == 2:
#         acc += ca
#         if ca == c:
#             k = 3
#         else:
#             k = 1
#     else:
#         acc += bc
#         if bc == c:
#             k = 2
#         else:
#             k = 1
#     n -= 1
# print(acc)
#
# #######################################
# #############
# n = int(input())
# pl = []
# s = input()
# s = s.split()
# for i in s:
#     pl.append(int(i))
#
# count = 0
# for i in pl:
#     if i==2:
#         count+=1
#
# t = len(pl)
# if t-count>=count:
#     print(count + (t - count*2) // 3)
# else:
#     print(t - count)
#
# #######################################
# #############
# n = int(input())
# lst = []
# for x in input().split():
#     lst.append(int(x))
# lst.sort()
#
# k = 50000
# for x in range(len(lst) - 1):
#     for y in range(x + 1, len(lst)):
#         acc = 0
#         a = lst[:x] + lst[x + 1:y] + lst[y + 1:]
#         for z in range(0, len(a) - 1, 2):
#             acc += a[z + 1] - a[z]
#         k = min(k, acc)
# print(k)
#
# #######################################
# #############
# (n, p, q, r) = map(int, input().split())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# a = - 10 ** 20
# b = - 10 ** 20
# c = - 10 ** 20
# for x in lst:
#     a = max(a, x * p)
#     b = max(b, a + x * q)
#     c = max(c, b + x * r)
#     #print((a, b, c), x)
#
# print(c)
#
# #######################################
# #############
# (n, m) = map(int, input().split())
#
# array = [0] * (n + 1)
# lst = []
# for x in range(m):
#     (s, d, c) = map(int, input().split())
#     lst.append((d, s, c, x + 1))
#
# lst.sort()
# i = 0
# flag = True
# for (d, s, c, p) in lst:
#     x = s
#     while c > 0 and x < d:
#         if array[x] == 0:
#             array[x] = p
#             c -= 1
#         x += 1
#     if c != 0:
#         flag = False
#         break
#     else:
#         array[d] = m + 1
#
# if flag:
#     print(*array[1:])
# else:
#     print(-1)
#
# #######################################
# #############
# n=int(input())
# s=input()
# if s=='0':
#     print('NO')
#     exit()
# for i in range(n-1):
#     if s[i]==s[i+1]=='1':
#         print('NO')
#         exit()
# for i in range(1,n-1):
#     if s[i]==s[i-1]==s[i+1]=='0':
#         print('NO')
#         exit()
# if n>1:
#     if s[0]==s[1]=='0' or s[-1]==s[-2]=='0':
#         print('NO')
#         exit()
# print('YES')
#
# #######################################
# #############
# n=int(input())
# s=input()
# if s=='0':
#     print(0)
# else:
#     print('1'+'0'*s.count('0'))
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# n=int(input())
# a=read()
# B=0
# C=0
# for i in a:
#     if i>0:
#         B+=i
#     else:
#         C+=i
# print(B-C)
#
# #######################################
# #############
# n = int(input())
#
# s = input()
#
# d = {}
# for x in range(n - 1):
#     if not s[x:x + 2] in d:
#         d[s[x:x + 2]] = 0
#     d[s[x:x + 2]] += 1
#
# a = 0
# for (x, y) in d.items():
#     if y > a:
#         a = y
#         w = x
#
# print(w)
#
#
# #######################################
# #############
# n = int(input())
# s = '?' + input() + '?'
#
# flag = False
# for x in range(1, len(s) - 1):
#     if s[x] == '?':
#         k = 0
#         for y in ['C', 'Y', 'M']:
#             if s[x - 1] != y and s[x + 1] != y:
#                 k += 1
#         if k > 1:
#             flag = True
#     elif s[x - 1] == s[x] or s[x + 1] == s[x]:
#         flag = False
#         break
#
# if flag:
#     print("Yes")
# else:
#     print("No")
#
# #######################################
# #############
# n,a,b=map(int,input().split())
# x=list(range(1,n+1))
# y=[]
# j=0
# while len(x)>2:
#     for i in range(0,n,2):
#         if x[i]==a and x[i+1]==b or x[i]==b and x[i+1]==a:
#             print(j+1)
#             exit()
#         if x[i+1]==a or x[i+1]==b:
#             y.append(x[i+1])
#         else:
#             y.append(x[i])
#     x=y.copy()
#     y=[]
#     n//=2
#     j+=1
# print('Final!')
#
#
#
#
#
# #######################################
# #############
# def main():
#     n = int(input())
#
#     if n < 6:
#         print(-1)
#     else:
#         for x in range(2, n // 2 + 2):
#             print(1, x)
#         for x in range(n // 2 + 2, n + 1):
#             print(2, x)
#
#     for x in range(n - 1):
#         print(x + 1, x + 2)
#
# main()
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# n=int(input())
# a=read()
# a.sort()
# j=0
# ans1=0
# for i in range(1,n+1,2):
#     ans1+=abs(a[j]-i)
#     j+=1
# j=0
# ans2=0
# for i in range(2,n+1,2):
#     ans2+=abs(a[j]-i)
#     j+=1
# print(min(ans1,ans2))
#
#
#
#
# #######################################
# #############
# a = int(input())
# b = int(input())
#
# if abs(a - b) % 2 == 0:
#     print((abs(a - b) // 2) * (abs(a - b) // 2 + 1))
# else:
#     print((abs(a - b) // 2) * (abs(a - b) // 2 + 1) + (abs(a - b) + 1) // 2)
#
# #######################################
# #############
# (n, k) = map(int, input().split())
#
# lst = []
# for x in range(n):
#     (a, b) = map(int, input().split())
#     lst.append((a, b))
#
# lst.sort()
#
# rs = 0
# for (a, b) in lst:
#     if a <= rs and b > rs:
#         rs = b
#
# if rs == k:
#     print("YES")
# else:
#     print("NO")
#
# #######################################
# #############
# n = int(input())
# count = 0
# for i in range(1, n+1):
#   for j in range((i+1)//2, i):
#       k = i^j
#       if k<=j and k<=n and k+j>i:
#         count+=1
#
#
# print(count)
# #######################################
# #############
# n = int(input())
# dic = {}
# for i in range(2, n+1):
#     x = int(input())
#     if x not in dic.keys():
#         dic.update({x:[]})
#         dic[x].append(i)
#     else:
#         dic[x].append(i)
# for x in dic.keys():
#     c = []
#     for y in dic[x]:
#         if y not in dic.keys():
#             c.append(y)
#     dic[x] = c
# st = True
# for y in dic.values():
#     if len(y)<3:
#         st = False
#         break
# if st:
#     print('Yes')
# else:
#     print('No')
# #######################################
# #############
# n=int(input())
# a=list(map(str,input()))
# i=0
# while i<n-1:
#     if a[i]!=a[i+1]:
#         a[i]='D'
#         del a[i+1]
#         n-=1
#     i+=1
# print(len(a))
#
# #######################################
# #############
# n,k=map(int,input().split())
# a=set()
# for i in range(1,k+1):
#     if n%i in a:
#         print('No')
#         exit()
#     else:
#         a.add(n%i)
# print('Yes')
#
# #######################################
# #############
# s = input()
#
# if '1' in s:
#     first = s.index('1')
#     k = s[first:].count('0')
#     if k >= 6:
#         print("yes")
#     else:
#         print("no")
# else:
#     print("no")
#
# #######################################
# #############
# (n, a, b) = map(int, input().split())
#
# lst = list(input())
#
# k = 0
# array = []
# for x in range(n):
#     if lst[x] == '*':
#         array.append(k)
#         k = 0
#     else:
#         k += 1
#
# if lst[0] == '*':
#     array = array[1:]
# if lst[-1] != '*':
#     array.append(k)
#
# s = a + b
# for x in array:
#     if max(a, b) == a:
#         p = (x + 1) // 2
#         a = max(a - p, 0)
#         b = max(b - (x - p), 0)
#     else:
#         p = (x + 1) // 2
#         b = max(b - p, 0)
#         a = max(a - (x - p), 0)
#
# print(s - (a + b))
#
# #######################################
# #############
# import math
#
# n, k = map(int, input().split())
# if k == 1:
#     print(n)
# else:
#     x = math.floor(math.log2(n)) + 1
#     if 2 ** (x - 1) > n:
#         print(2 ** (x - 1) - 1)
#     else:
#         print(2 ** x - 1)
#
# #######################################
# #############
# import math
# n = int(input())
# s = input().split()
# a = []
# for i in s:
#     a.append(int(i))
# a.sort()
# a = a[::-1]
# for i in a:
#     if i<0:
#         print(i)
#         break
#     else:
#         if math.sqrt(i)!=int(math.sqrt(i)):
#             print(i)
#             break
#
# #######################################
# #############
# s1 = input()
# s2 = input()
# s1 = s1.split()
# s2 = s2.split()
# n = int(s1[0])
# k = int(s1[1])
# a = []
# for i in s2:
#     a.append(int(i))
#
# a.sort()
# t = n-1
# while(t>=0):
#     if k%a[t]==0:
#         print(int(k/a[t]))
#         break
#     else:
#         t-=1
# #######################################
# #############
# s  = input().split()
# a = int(s[0])
# b = int(s[1])
#
# while(a!=0 and b!=0):
#     if a>=2*b:
#         a = a%(2*b)
#
#     else:
#         if b<2*a:
#             break
#         else:
#             b = b%(2*a)
#
# print('{} {}'.format(a, b))
# #######################################
# #############
# s = input().split()
# n = int(s[0])
# k = int(s[1])
# t = 0
# res = 0
#
# while(2**t<=n):
#   t+=1
# if k==1:
#   res = n
# else:
#   res = 0
#   i = 0
#   while(i<t):
#     res+=2**i
#     i+=1
#
# print(res)
# #######################################
# #############
# n = int(input())
# a = []
# b = []
# a.append(n)
# b.append(n-1)
# c1 = n
# c2 = n-1
# k = n-2
# while(k>0):
#     if abs(k+c1-c2)<abs(k+c2-c1):
#         a.append(k)
#         c1+=k
#     else:
#         b.append(k)
#         c2+=k
#     k-=1
# s = ''
# for i in a:
#     s+=str(i) + ' '
# print(abs(c1-c2))
# print(str(len(a)) + ' ' + s)
# #######################################
# #############
# n = int(input())
# s = input()
# cl = ['a', 'o', 'u', 'e', 'i', 'y']
# res = ''
# res+=s[0]
# for i in range(1, n):
#     if res[-1] in cl and s[i] in cl:
#         pass
#     else:
#         res+=s[i]
#
# print(res)
# #######################################
# #############
# (n, w) = map(int, input().split())
#
# lst = [int(x) for x in input().split()]
#
# a = [0]
# for x in range(n):
#     a.append(a[x] + lst[x])
#
# maxi = max(a)
# mini = min(a)
#
# if maxi > w or w + mini < 0:
#     print(0)
# else:
#     print(max((w - maxi) + mini + 1, 0))
#
#
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in range(n):
#     x = int(input())
#     lst.append(x)
#
# i = 3
# flag = True
# for x in lst:
#     if i == x:
#         flag = False
#         break
#     else:
#         if i + x == 4:
#             i = 2
#         elif i + x == 5:
#             i = 1
#         else:
#             i = 3
#
# if flag:
#     print("YES")
# else:
#     print("NO")
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# s=input()
# kb=s.count('o')
# kn=s.count('-')
# if kb==0:
#     print('YES')
#     exit()
# if kn%(kb)==0:
#     print('YES')
# else:
#     print('NO')
#
# #######################################
# #############
# n = int(input())
# cl = []
# dic = {}
# res = [0]*n
# for i in range(n):
#   x = eval(input())
#   if x not in dic.keys():
#     dic.update({x:[]})
#     dic[x].append(i)
#   else:
#     dic[x].append(i)
#
# for x in dic.values():
#   k = len(x)
#   for y in x:
#     res[y]=k
#
# result = ''
# for x in res:
#   result+=str(x)+' '
#
# print(result)
# #######################################
# #############
# import atexit
# import io
# import sys
#
# # Buffering IO
# _INPUT_LINES = sys.stdin.read().splitlines()
# input = iter(_INPUT_LINES).__next__
# _OUTPUT_BUFFER = io.StringIO()
# sys.stdout = _OUTPUT_BUFFER
#
# @atexit.register
# def write():
#     sys.__stdout__.write(_OUTPUT_BUFFER.getvalue())
#
#
# def main():
#     n = int(input())
#     ss = input().split()
#     s = set()
#     for x in ss:
#         s.add(''.join(sorted(list(set(x)))))
#     print(len(s))
#
#
#
#
# if __name__ == '__main__':
#     main()
# #######################################
# #############
# s = input()[::-1]
# count=0
# st = False
# for i in s:
#   if i=='0':
#     count+=1
#   else:
#     if count>=6:
#       st = True
#       break
#
# if st:
#   print('yes')
# else:
#   print('no')
# #######################################
# #############
# s1 = input()
# w = s1.split()
# x = int(w[0])
# n = int(w[1])
# s2 = input()
# s2 = s2.split()
# r = []
# for i in range(x):
#     r.append(int(s2[i]))
# s = 0
# for j in r:
#     s+=j
# if s + len(r)-1 == n:
#     print('Yes')
# else:
#     print('No')
#
# #######################################
# #############
# a=[]
# n,N=map(int,input().split())
# for i in range(n):
#     a.append(input())
# for i in range(n):
#     for j in range(N):
#         m=(i and a[i-1][j]=='*')+(j and a[i][j-1]=='*')+(i<n-1 and a[i+1][j]=='*')+(j<N-1 and a[i][j+1]=='*')+(i and j and a[i-1][j-1]=='*')+(i<n-1 and j<N-1 and a[i+1][j+1]=='*')+(i and j<N-1 and a[i-1][j+1]=='*')+(i<n-1 and j and a[i+1][j-1]=='*')
#         if a[i][j]=='.' and m!=0 or '1'<=a[i][j]<='8' and int(a[i][j])!=m:
#             print('NO')
#             exit()
# print('YES')
#
#
#
#
# #######################################
# #############
# n = int(input())
# s = input().split()
# mx = 0
# for x in s:
#     t = s.count(x)
#     if t>mx:
#         mx = t
#
# print(mx)
#
# #######################################
# #############
# n = int(input())
# dic = {}
# for i in range(n):
#     a = input().split()
#     dic[int(a[0])]=int(a[1])
#
# m = int(input())
# for j in range(m):
#     b = input().split()
#     if int(b[0]) in dic.keys():
#         dic[int(b[0])]=max(dic[int(b[0])], int(b[1]))
#     else:
#         dic[int(b[0])] = int(b[1])
#
# print(sum(dic.values()))
# #######################################
# #############
# n = int(input())
#
# a = str(n)
# lst = []
# k = 0
# if len(a) == 1:
#     if n % 2 == 0:
#         print(1)
#         print(n // 2)
#     else:
#         print(0)
# else:
#     for x in range(n - (len(a) - 1) * 10, n):
#         s = str(x)
#         acc = x
#         for z in s:
#             acc += int(z)
#         if acc == n:
#             lst.append(x)
#             k += 1
#     print(k)
#     if k != 0:
#         for x in lst:
#             print(x)
#
# #######################################
# #############
# n = int(input())
# doc = []
# for i in range(n):
#   s = input()
#   doc.append((i+1, int(s.split()[0]), int(s.split()[1])))
#
# count = 1
# cd = 0
# while(cd<n):
#
#   if count-doc[cd][1]>=0 and (count-doc[cd][1])%doc[cd][2]==0:
#     cd+=1
#
#   count+=1
#
# print(count-1)
# #######################################
# #############
# s=input()
# c=s+''
# a=[]
# b=['b', 'c', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'y', 'z']
# for i in range(2,len(s)):
#     if not(c[i-2]==c[i-1]==c[i]) and c[i-2] in b and c[i-1] in b and c[i] in b:
#         a.append(i)
#         c=c[:i-1]+'a'+c[i:]
# for i in range(len(s)):
#     if i in a:
#         print(' '+s[i],end='')
#     else:
#         print(s[i],end='')
#
# #######################################
# #############
# def read():
#     return list(map(int,input().split()))
# s=input()
# for i in range(len(s)):
#     if s[i]=='0':
#         s=s[:i]+'o'+s[i+1:]
#     elif s[i]=='1' or s[i]=='i' or s[i]=='I':
#         s=s[:i]+'l'+s[i+1:]
# a=[]
# n=int(input())
# for i in range(n):
#     c=input()
#     for i in range(len(c)):
#         if c[i]=='0':
#             c=c[:i]+'o'+c[i+1:]
#         elif c[i]=='1' or c[i]=='i' or c[i]=='I':
#             c=c[:i]+'l'+c[i+1:]
#     if c.capitalize()==s.capitalize():
#         print('No')
#         exit()
# print('Yes')
#
#
#
#
# #######################################
# #############
# n=int(input())
# g=[0 for i in range(n)]
# for i in range(n-1):
#     a,b=map(int,input().split())
#     g[a-1]+=1
#     g[b-1]+=1
# q=0
# k=0
# kind=0
# m=0
# for i in range(n):
#     if g[i]==1:
#         m+=1
#     if g[i]>2:
#         if g[i]>k:
#             kind=i
#             k=g[i]
#         q+=1
# if q>1:
#     print('No')
# else:
#     print('Yes')
#     if k>2:
#         print(m)
#         for i in range(n):
#             if g[i]==1:
#                 print(kind+1,i+1)
#     else:
#         print(1)
#         for i in range(n):
#             if g[i]==1:
#                 print(i+1,end=' ')
#
# #######################################
# #############
# n,k=map(int,input().split())
# b=list(map(int,input().split()))
# s=input()
# a=[]
# if k==1:
#     print(-1)
#     exit()
# for i in range(n):
#     a.append((b[i],s[i]))
# a.sort(reverse=True)
# i=0
# j=0
# m1=0
# q1=False
# q2=False
# while i!=k:
#     if a[j][1]!='R':
#         m1+=a[j][0]
#         g=j+0
#         if a[j][1]=='W':
#             q1=True
#         else:
#             q2=True
#         i+=1
#     j+=1
#     if j==n and i!=k:
#         m1=0
#         break
# else:
#     if not (q1 and q2):
#         m1-=a[g][0]
#         for i in range(g+1,n):
#             if q1 and a[i][1]=='O' or q2 and a[i][1]=='W':
#                 m1+=a[i][0]
#                 break
#         else:
#             m1=0
# i=0
# j=0
# m2=0
# q1=False
# q2=False
# while i!=k:
#     if a[j][1]!='W':
#         m2+=a[j][0]
#         g=j+0
#         if a[j][1]=='R':
#             q1=True
#         else:
#             q2=True
#         i+=1
#     j+=1
#     if j==n and i!=k:
#         m2=0
#         break
# else:
#     if not (q1 and q2):
#         m2-=a[g][0]
#         for i in range(g+1,n):
#             if q1 and a[i][1]=='O' or q2 and a[i][1]=='R':
#                 m2+=a[i][0]
#                 break
#         else:
#             m2=0
# if m1 or m2:
#     print(max(m1,m2))
# else:
#     print(-1)
#
#
#
#
#
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in range(n):
#     (a, b) = map(int, input().split())
#     lst.append((a, b))
#
# def scal(x1, y1, x2, y2, x3, y3):
#     if (x2 - x1) * (y3 - y1) - (x3 - x1) * (y2 - y1) == 0:
#         return True
#     return False
#
# def check():
#     for x in range(n - 2):
#         if len(s2) >= 3:
#             if not scal(lst[s2[-3]][0], lst[s2[-3]][1], lst[s2[-2]][0], lst[s2[-2]][1], lst[s2[-1]][0], lst[s2[-1]][1]):
#                 return False
#         if scal(lst[0][0], lst[0][1], lst[1][0], lst[1][1], lst[x + 2][0], lst[x + 2][1]):
#             s1.append(x + 2)
#         else:
#             s2.append(x + 2)
#     if len(s2) >= 3:
#         if not scal(lst[s2[-3]][0], lst[s2[-3]][1], lst[s2[-2]][0], lst[s2[-2]][1], lst[s2[-1]][0], lst[s2[-1]][1]):
#             return False
#     return True
#
# flag = True
#
# if n >= 5:
#     s1 = []
#     s2 = []
#     if not check():
#         lst[1], lst[s2[0]] = lst[s2[0]], lst[1]
#         x = s2[0]
#         s1 = []
#         s2 = []
#         if not check():
#             lst[0], lst[s2[0]] = lst[s2[0]], lst[0]
#             s1 = []
#             s2 = []
#             if not check():
#                 flag = False
#
# if flag:
#     print("YES")
# else:
#     print("NO")
#
# #######################################
# #############
# s = input()
#
# string = ""
# k = ord('a')
# for x in s:
#     if ord(x) <= k:
#         string = string + chr(k)
#         k = min(ord('z'), k + 1)
#     else:
#         string = string + x
#
# if k == ord('z') and string[-1] == 'z':
#     print(string)
# else:
#     print(-1)
#
# #######################################
# #############
# import math
# s = input().split()
# r= int(s[0])
# x1= int(s[1])
# y1= int(s[2])
# x2= int(s[3])
# y2= int(s[4])
# if (x2-x1)**2+(y2-y1)**2>r**2:
#     print('{} {} {}'.format(x1, y1, r))
# else:
#     if x2 - x1==0:
#         nx1 = x1
#         nx2 = x1
#         ny1 = y1+r
#         ny2 = y1-r
#     else:
#         k = (y2-y1)/(x2-x1)
#         nx1 = math.sqrt(r**2/(k**2+1))+x1
#         nx2 = -math.sqrt(r**2/(k**2+1))+x1
#         ny1 = k*(nx1-x1)+y1
#         ny2 = k*(nx2 - x1)+y1
#     if math.sqrt((ny1-y2)**2+(nx1-x2)**2)>math.sqrt((ny2-y2)**2+(nx2-x2)**2):
#         print('{} {} {}'.format((nx1+x2)/2, (ny1+y2)/2,  math.sqrt((ny1-y2)**2+(nx1-x2)**2)/2))
#     else:
#         print('{} {} {}'.format((nx2 + x2) / 2, (ny2 + y2) / 2, math.sqrt((ny2 - y2) ** 2 + (nx2 - x2) ** 2) / 2))
#
# #######################################
# #############
# import sys
# a=[]
# for i in range(6):
#     print(i)
#     a.append(input())
#     sys.stdout.flush()
# if 'cool' in a or 'great' in a or 'don'+"'"+'t think so' in a or 'don'+"'"+'t touch me!' in a or 'not bad' in a:
#     print('normal')
# else:
#     print('grumpy')
#
# #######################################
# #############
# (n, m, k) = map(int, input().split())
#
# if k <= n - 1:
#     print(1 + k, 1)
# else:
#     k -= n
#     d = k // (m - 1)
#     k %= (m - 1)
#     if d % 2 == 0:
#         print(n - d, k + 2)
#     else:
#         print(n - d, m - k)
#
# #######################################
# #############
# s = input().split()
# n = int(s[0])
# m = int(s[1])
# s = list(map(int, input().split()))
# dic = {}
# for i in range(n):
#     dic.update({i+1:0})
# for x in s:
#     dic[x]+=1
#
# mn = 10**9
# for x in dic.keys():
#     if dic[x]<mn:
#         mn = dic[x]
#
# print(mn)
# #######################################
# #############
# n,k=map(int,input().split())
# a=list(map(int,input().split()))
# a.sort()
# if k==n:
#     print(a[k-1])
# elif k==0:
#     if a[0]==1:
#         print(-1)
#     else:
#         print(1)
# else:
#     k-=1
#     if a[k]==a[k+1]:
#         print(-1)
#     else:
#         print(a[k])
#
# #######################################
# #############
# def read():
#     return map(int,input().split())
# y,x=read()
# if x==1 and y>0:
#     print('NO')
#     exit()
# x-=1
# if x==-1 or y<x or (y-x)%2:
#     print('NO')
# else:
#     print('YES')
# #######################################
# #############
# n = int(input())
# g = []
# for i in range(n):
#     g.append(int(input()))
#
# res = 'YES'
# st1 = [1, 2, 3]
# st2 = [0, 0, 0]
# gres = []
# gres.append(tuple(st1))
# for i in range(n):
#     d = g[i]
#     st2[0] = d
#     st2[1] = st1[2]
#     for i in range(1, 4):
#         if i!=st2[0] and i!=st2[1]:
#             st2[2] = i
#     st1 = st2
#     gres.append(tuple(st2))
#
# for i in range(len(gres)-1):
#     if gres[0][0]==3:
#         res = 'NO'
#         break
#     if gres[i][2]==gres[i+1][0]:
#         res = 'NO'
#         break
#
#
# print(res)
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x) - 1)
#
# mass = [0] * n
# for x in range(1, n):
#     mass[x] = mass[lst[x - 1]] + 1
#
# d = {}
# for x in mass:
#     if not x in d:
#         d[x] = 0
#     d[x] += 1
#
# k = 0
# for (key, value) in d.items():
#     k += value % 2
#
# print(k)
#
# #######################################
# #############
# s = input().split()
# n = int(s[0])
# a = int(s[1])
# b = int(s[2])
# mx = a+b
# st = False
# while(mx>=1):
#   if st:
#     break
#   for i in range(1, n):
#     if st:
#       break
#     for j in range(1, n):
#       if i*mx<=a and j*mx<=b and i+j==n:
#         print(mx)
#         st = True
#         break
#   mx-=1
# #######################################
# #############
# n = int(input())
# s = input()
# s = s.split()
# d = []
# m1 = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
# m2 = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
# m3 = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31, 31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
# m = []
# m.append(m1)
# m.append(m2)
# m.append(m3)
#
# for i in s:
#     d.append(int(i))
#
# st = False
# for a in m:
#     if st:
#         break
#     for x in range(24):
#         y = []
#         if x+n>24:
#             c1 = a[x:]
#             c2 = a[:x+n-24]
#             y = c1 + c2
#         else:
#             y = a[x:x+n]
#         if y==d:
#             st = True
#
# if st:
#     print('Yes')
# else:
#     print('No')
# #######################################
# #############
# (v1, v2, v3, v) = map(int, input().split())
#
# if v > 2 * v3 or v * 2 < v3 or v >= v2:
#     print(-1)
# else:
#     print(2 * v1)
#     print(2 * v2)
#     print(max(v, v3))
#
# #######################################
# #############
# n = int(input())
# s = input().split()
# st = False
# for i in s:
#     if i!=s[int(i)-1] and s[int(i)-1]!=s[int(s[int(i)-1])-1] and i!=s[int(s[int(i)-1])-1] and s[int(s[int(s[int(i)-1])-1])-1]==i:
#         st = True
#         break
#
# if st:
#     print('YES')
# else:
#     print('NO')
# #######################################
# #############
# import re
# s=input()
# try:
#     print('YES' if re.match(r'aa*bb*cc*',s).group(0)==s and (s.count('a')==s.count('c') or s.count('b')==s.count('c')) else 'NO')
# except:
#     print('NO')
#
#
# #######################################
# #############
# r,x1,y1,x2,y2=map(int,input().split())
# if (x2-x1)**2+(y2-y1)**2>=r*r:
#     print(x1,y1,r)
#     exit()
# if x1==x2:
#     if y2<y1:
#         print(x1,y2+(y1+r-y2)/2,(y1+r-y2)/2)
#     else:
#         print(x1,y2-(y2-y1+r)/2,(y2-y1+r)/2)
# else:
#     k=(y2-y1)/(x2-x1)
#     b=y1-k*x1
#     B=b+0
#     a=k*k+1
#     c=x1*x1+b*b-2*b*y1+y1*y1-r*r
#     b=2*k*b-2*x1-2*k*y1
#     d=b*b-4*a*c
#     X1=(-b+d**0.5)/(2*a)
#     X2=(-b-d**0.5)/(2*a)
#     Y1=k*X1+B
#     Y2=k*X2+B
#     r1=((X1-x2)**2+(Y1-y2)**2)**0.5
#     r2=((X2-x2)**2+(Y2-y2)**2)**0.5
#     if r1>r2:
#         print((x2+X1)/2,(y2+Y1)/2,r1/2)
#     else:
#         print((x2+X2)/2,(y2+Y2)/2,r2/2)
#
#
#
# #######################################
# #############
# s = input().split()
# r, c = int(s[0]), int(s[1])
# p = []
# for i in range(r):
#     s = input()
#     t = []
#     for j in range(c):
#         t.append(s[j])
#     p.append(t)
#
# res = True
# for i in range(r):
#     if not res:
#         break
#     for j in range(c):
#         if p[i][j]=='S':
#             if (i-1>=0 and p[i-1][j]=='W') or (i+1<=r-1 and p[i+1][j]=='W') or (j-1>=0 and p[i][j-1]=='W') or (j+1<=c-1 and p[i][j+1]=='W'):
#                 res = False
#                 break
#             if i-1>=0 and p[i-1][j]=='.':
#                 p[i-1][j]='D'
#             if i+1<=r-1 and p[i+1][j]=='.':
#                 p[i+1][j]='D'
#             if j+1<=c-1 and p[i][j+1]=='.':
#                 p[i][j+1]='D'
#             if j-1>=0 and p[i][j-1]=='.':
#                 p[i][j-1]='D'
#
#
# if res:
#     print('Yes')
#     ns = ''
#     for i in range(r):
#         e = ''
#         for j in range(c):
#             e+=p[i][j]
#         print(e)
# else:
#     print('No')
#
# #######################################
# #############
# print(int(input())//2+1)
# #######################################
# #############
# n=int(input())
# a=list(map(int,input().split()))
# q=1
# for i in range(n-1):
#     if q==1:
#         a.remove(max(a))
#     else:
#         a.remove(min(a))
#     q*=-1
# print(a[0])
#
#
#
# #######################################
# #############
# n = int(input())
#
# a = []
# for x in range(n):
#     x = input()
#     a.append(x)
#
# lst = []
# for x in a:
#     if not x in lst:
#         print('NO')
#         lst.append(x)
#     else:
#         print('YES')
#
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# def main():
#     maxi = max(lst)
#     mini = min(lst)
#     if maxi - mini < 2:
#         print(n)
#         print(*lst)
#     else:
#         MIN = 0
#         MAX = 0
#         k2 = 0
#         for x in lst:
#             if x == mini:
#                 MIN += 1
#             elif x == maxi:
#                 MAX += 1
#             else:
#                 k2 += 1
#         k1 = min(MIN, MAX)
#         if 2 * k1 >= k2:
#             count_min = 0
#             count_max = 0
#             for x in range(len(lst)):
#                 if lst[x] == mini and count_min < k1:
#                     lst[x] += 1
#                     count_min += 1
#                 elif lst[x] == maxi and count_max < k1:
#                     lst[x] -= 1
#                     count_max += 1
#             print(k2 + abs(MIN - MAX))
#             print(*lst)
#         else:
#             k = 0
#             if k2 % 2 == 1:
#                 k += 1
#             k2 = k2 // 2
#             count_min = 0
#             count_max = 0
#             for x in range(len(lst)):
#                 if lst[x] == maxi - 1:
#                     if count_max > count_min and count_min < k2:
#                         count_min += 1
#                         lst[x] -= 1
#                     else:
#                         if count_max < k2:
#                             count_max += 1
#                             lst[x] += 1
#             print(k + MIN + MAX)
#             print(*lst)
#
# main()
#
# #######################################
# #############
# n = int(input())
# block = []
# s = list(map(int, input().split()))
# a = s[::-1]
# rest = []
# count = 0
# for i in range(n):
#  if a[i] not in block:
#   rest.append(str(a[i]))
#   block.append(a[i])
#   count+=1
#
# rest = rest[::-1]
# res = ''
# for i in range(count):
#  res+=rest[i]+' '
# print(count)
# print(res)
# #######################################
# #############
# s = input().split()
# n = int(s[0])
# k = int(s[1])
# st = True
# mod = []
# for i in range(1, k+1):
#   if i>n+1:
#     st = False
#     break
#   x = n%i
#   if x not in mod:
#     mod.append(x)
#   else:
#     st = False
#     break
#
# if st:
#   print('Yes')
# else:
#   print('No')
# #######################################
# #############
# (n, a, b) = map(int, input().split())
#
# a -= 1
# b -= 1
#
# a //= 2
# b //= 2
# k = 1
# while a != b and n != 2:
#     a //= 2
#     b //= 2
#     n //= 2
#     k += 1
#
# if n == 2:
#     print("Final!")
# else:
#     print(k)
#
# #######################################
# #############
# (n, pos, l, r) = map(int, input().split())
#
# if pos in range(l, r + 1):
#     if l != 1 and r != n:
#         print((min(r - pos, pos - l) + 1) + ((r - l) + 1))
#     elif l != 1:
#         print(pos - l + 1)
#     elif r != n:
#         print(r - pos + 1)
#     else:
#         print(0)
# else:
#     if l != 1 and r != n:
#         if pos >= r:
#             print((pos - r + 1) + ((r - l) + 1))
#         else:
#             print((l - pos + 1) + ((r - l) + 1))
#     elif l != 1:
#         print(l - pos + 1)
#     elif r != n:
#         print(pos - r + 1)
#     else:
#         print(0)
#
# #######################################
# #############
# import math
# h,m=map(int,input().split())
# H,D,C,N=map(int,input().split())
# if h>=20:
#     print(C*0.8*math.ceil(H/N))
# else:
#     k=(20-h-1)*60+60-m
#     print(min(C*math.ceil(H/N),C*0.8*math.ceil((H+D*k)/N)))
#
# #######################################
# #############
# n=int(input())
# a=list(sorted(map(int,input().split())))
# b=[]
# for i in a:
#     if not i in b:
#         b.append(i)
# if 0 in a:
#     print(len(b)-1)
# else:
#     print(len(b))
#
#
# #######################################
# #############
# import math
#
# n = int(input())
#
# k = 0
# for x in range(2, math.floor(math.sqrt(n)) + 1):
#     if n % x == 0:
#         if x * x != n:
#             k += 2
#         else:
#             k += 1
#
# print(k + 1)
#
# '''
# n = int(input())
#
# s = input()
#
# x = 0
# y = 0
# for i in range(len(s) - 1):
#     if s[i] == 'U':
#         y += 1
#     else:
#         x += 1
#     if x == y:
#         if s[i] == s[i'''
#
# #######################################
# #############
# import math
# n = int(input())
#
# count = 0
# global check
# check = 10**9+1
# global cl
# cl = []
#
# def qw(n, count):
#     global check
#     global cl
#     if n in cl or count>=check:
#         return
#     cl.append(n)
#     if isq(n):
#         if count<check:
#             check = count
#             return
#     else:
#         count+=1
#         s = str(n)
#         if len(s)==1:
#             return
#         for x in range(len(s)):
#             if x==0:
#                 if s[1]!='0':
#                     qw(int(s[:x]+s[x+1:]), count)
#
#             else:
#                 qw(int(s[:x] + s[x + 1:]), count)
#
#
# def isq(n):
#     if int(math.sqrt(n))**2==n:
#         return True
#     else:
#         return False
#
#
# qw(n, count)
#
# if check ==10**9+1:
#     print(-1)
# else:
#     print(check)
# #######################################
# #############
# n = int(input())
# m = int(input())
#
# if n > 29:
#     print(m)
# else:
#     print(m % (2 ** n))
#
# #######################################
# #############
# n = int(input())
#
# d = {}
# for x in input().split():
#     x = int(x)
#     if not x in d:
#         d[x] = 0
#     d[x] += 1
#
# d = sorted(d.items(), reverse = True)
# k = 0
# flag = False
# for (x, y) in d:
#     k += y
#     if k % 2 == 1:
#         flag = True
#         break
#
# if flag:
#     print("Conan")
# else:
#     print("Agasa")
#
# #######################################
# #############
# n,k=map(int,input().split())
# a=list(map(int,input().split()))
# m=100000000000000000000000000000000000000000
# for i in range(k):
#     if n%a[i]<m:
#         m=n%a[i]
#         ans2=i+1
#         ans1=n//a[i]
# print(ans2,ans1)
#
#
#
# #######################################
# #############
# import math
# x,y=map(int,input().split())
# if x==1 or y==1:
#     if x**y==y**x:
#         print('=')
#     elif x**y>y**x:
#         print('>')
#     else:
#         print('<')
#     exit()
# x,y=y,x*math.log(y,x)
# if x==y:
#     print('=')
# elif x>y:
#     print('>')
# else:
#     print('<')
#
# #######################################
# #############
# print(int(input())%2)
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x) - 1)
#
# flag = False
# for x in range(len(lst)):
#     if x == lst[lst[lst[x]]]:
#         flag = True
#         break
#
# if flag:
#     print("YES")
# else:
#     print("NO")
#
# #######################################
# #############
# n = int(input())
#
# s = str(n)
# lst = []
# t = set()
# def xxx(string):
#     if string[0] == '0':
#         return
#     x = int(string)
#
#
#     if x in t:
#         return
#     t.add(x)
#
#     k1 = 0
#     k2 = 10 ** 6
#     while k2 - k1 != 1:
#         k = (k1 + k2) // 2
#         if k ** 2 <= x:
#             k1 = k
#         else:
#             k2 = k
#     if k1 ** 2 == x:
#         lst.append(len(str(x)))
#
#     if len(string) == 1:
#         return
#     for x in range(len(string)):
#         xxx(string[:x] + string[x + 1:])
#     return
#
# xxx(s)
# if len(lst) == 0:
#     print(-1)
# else:
#     print(len(s) - max(lst))
#
# #######################################
# #############
# s = input()
#
# k1 = 0
# k2 = 0
# for x in s:
#     if x == 'o':
#         k1 += 1
#     else:
#         k2 += 1
#
# if k1 == 0:
#     print("YES")
# elif k2 % k1 == 0:
#     print("YES")
# else:
#     print("NO")
#
# #######################################
# #############
# n = int(input())
#
# lst = []
# d = {}
# k = -1
# for x in input().split():
#     k += 1
#     d[x] = k
#
# m = 0
# for (x, y) in d.items():
#     if y < n:
#         n = y
#         m = x
#
# print(m)
#
#
# #######################################
# #############
# ps = input()
# ps = ps.split()
# n = int(ps[0])
# m = int(ps[1])
# st = input()
# op = []
# for i in range(m):
#     x = []
#     ak = input().split()
#     op.append([int(ak[0]), int(ak[1]), ak[2], ak[3]])
#
# def oper(oplist, s):
#     ns = ''
#     c = 0
#     while(c<n):
#         if c>=oplist[0]-1 and c<=oplist[1]-1:
#             if s[c] == oplist[2]:
#                 ns+=oplist[3]
#             else:
#                 ns+=s[c]
#         else:
#             ns += s[c]
#         c+=1
#
#     return ns
#
# z = st
# for j in op:
#     z = oper(j, z)
#
# print(z)
# #######################################
# #############
# s = input()
# ls1 = ['a', 'e', 'u', 'i', 'o']
# ls2 = ['0', '2', '4', '6', '8']
# count = 0
# for c in s:
#     if c.isalpha():
#         if c in ls1:
#             count+=1
#     else:
#         if c not in ls2:
#             count+=1
#
#
# print(count)
# #######################################
# #############
# n = int(input())
#
# print(n * 2 - 1, 2)
# print(1, 2)
#
# #######################################
# #############
# n=int(input())
# a1={}
# s=input()
# for i in s:
#     if i in a1:
#         a1[i]+=1
#     else:
#         a1[i]=1
# a2={}
# s=input()
# for i in s:
#     if i in a2:
#         a2[i]+=1
#     else:
#         a2[i]=1
# a3={}
# s=input()
# for i in s:
#     if i in a3:
#         a3[i]+=1
#     else:
#         a3[i]=1
# m1=0
# m2=0
# m3=0
# for i in a1:
#     if a1[i]>m1:
#         m1=a1[i]
# for i in a2:
#     if a2[i]>m2:
#         m2=a2[i]
# for i in a3:
#     if a3[i]>m3:
#         m3=a3[i]
# if m1==len(s) and n==1:
#     m1=len(s)-1
# else:
#     m1=min(len(s),m1+n)
# if m2==len(s) and n==1:
#     m2=len(s)-1
# else:
#     m2=min(len(s),m2+n)
# if m3==len(s) and n==1:
#     m3=len(s)-1
# else:
#     m3=min(len(s),m3+n)
# if m1>m2 and m1>m3:
#     print('Kuro')
# elif m2>m1 and m2>m3:
#     print('Shiro')
# elif m3 > m1 and m3>m2:
#     print('Katie')
# else:
#     print('Draw')
#
#
# #######################################
# #############
# (n, k) = map(int, input().split())
#
# lst = []
# for x in input().split():
#     lst.append(int(x) - 1)
#
# array = []
#
# for x in range(len(lst)):
#     if lst[x] == -1:
#         t = (min(n, x + k + 1) - max(0, x - k), min(n, x + k + 1))
#     else:
#         t = (array[lst[x]][0] + min((min(n, x + k + 1) - array[lst[x]][1]), 1 + min(n - x - 1, k) + min(x + 1, k)), min(n, x + k + 1))
#     array.append(t)
#
# for (c, r) in array:
#     print(c, end = ' ')
# #######################################
# #############
# k=int(input())
# b=set()
# e=[]
# for i in range(k):
#     n=int(input())
#     a=list(map(int,input().split()))
#     s=sum(a)
#     c=[]
#     d=[s]
#     for j in range(n):
#         if s-a[j] in b:
#             print('YES')
#             print(i+1,j+1)
#             for k in range(len(e)):
#                 for p in range(1,len(e[k])):
#                     if e[k][0]-e[k][p]==s-a[j]:
#                         print(k+1,p)
#                         exit()
#         else:
#             c.append(s-a[j])
#         d.append(a[j])
#     for j in c:
#         b.add(j)
#     e.append(d)
# print('NO')
#
# #######################################
# #############
# (n, k) = map(int, input().split())
#
# if k > 5000:
#     k = 5000
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# s = []
# d = {}
# win = max(lst[0], lst[1])
# out = min(lst[0], lst[1])
# lst.remove(out)
# lst.append(out)
# s.append(win)
# d[win] = 1
# acc = 0
#
# while acc != k:
#     win = max(s[-1], lst[1])
#     out = min(s[-1], lst[1])
#     lst.remove(out)
#     lst.append(out)
#     s.append(win)
#     if not win in d:
#         d[win] = 0
#     d[win] += 1
#     acc = max(d.values())
#
# print(max(d))
#
#
# #######################################
# #############
# n = int(input())
# s = input()
# cl = []
# dic = {}
# for i in range(n-1):
#   if s[i:i+2] not in cl:
#     dic.update({s[i:i+2]:0})
#     cl.append(s[i:i+2])
#
# for i in range(n-1):
#   dic[s[i:i+2]]+=1
#
# inverse = [(value, key) for key, value in dic.items()]
# print(max(inverse)[1])
# #######################################
# #############
# n = int(input())
# s  = input().split()
# cl = []
# for i in s:
#     cl.append(int(i))
# cl = sorted(cl)
#
# mx = -10**9
# for i in range(n+1):
#     if abs(sum(cl[:i])-sum(cl[i:]))>mx:
#         mx = abs(sum(cl[:i])-sum(cl[i:]))
#
# print(mx)
#
# #######################################
# #############
# n = int(input())
# a = sorted(list(map(int, input().split())))
# if n%2==0:
#     print(a[n//2-1])
# else:
#     print(a[n//2])
# #######################################
# #############
# (n, k) = map(int, input().split())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# array = []
# for x in input().split():
#     array.append(int(x))
#
# mass1 = [0]
# for x in range(n):
#     mass1.append(mass1[-1] + lst[x])
#
# mass2 = [0]
# for x in range(n):
#     mass2.append(mass2[-1] + lst[x] * array[x])
#
# ans = 0
# for x in range(1, n - k + 2):
#     ans = max(ans, mass2[x - 1] + (mass1[x + k - 1] - mass1[x - 1]) + (mass2[-1] - mass2[x + k - 1]))
#     #print(ans, x)
#
# print(ans)
#
# #######################################
# #############
# n, a, b, c, t = map(int, input().split())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# if b > c:
#     print(n * a)
# else:
#     acc = 0
#     for x in lst:
#         acc += (t - x)
#     acc *= (c - b)
#     acc += n * a
#     print(acc)
#
#
# #######################################
# #############
# t = int(input())
# for i in range(t):
#     s = input().split()
#     n = int(s[0])
#     k = int(s[1])
#     a = []
#     z = input().split()
#     for d in z:
#         a.append(int(d))
#     mx = 0
#     for x in range(k-1):
#         if a[x+1]-a[x]>mx:
#             mx = a[x+1]-a[x]-1
#     if mx==0:
#         print(1+max(a[0]-1,n-a[-1]))
#     else:
#         if int(mx/2+0.5)>=max(a[0]-1,n-a[-1]):
#                 print(1+int(mx/2+0.5))
#         else:
#             print(1+ max(a[0]-1, n - a[-1]))
# #######################################
# #############
# s=input()
# l=len(s)
# for i in range(l-1,-1,-1):
#     s+=s[i]
# print(s)
#
# #######################################
# #############
# s = input().split()
# n, k1, k2 = int(s[0]), int(s[1]), int(s[2])
# k = k1+k2
# a = list(map(int, input().split()))
# b = list(map(int, input().split()))
# cl = []
# for i in range(n):
#   cl.append(abs(a[i]-b[i]))
# for i in range(k):
#   cl[cl.index(max(cl))] = abs(max(cl)-1)
#
# res = 0
# for x in range(n):
#     res+=cl[x]**2
#
# print(res)
# #######################################
# #############
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# m = int(input())
# pair = []
# for x in range(m):
#     (l, r) = map(int, input().split())
#     pair.append((l, r))
#
# k = 0
# for x in range(0, len(lst) - 1):
#     for y in range(x + 1, len(lst)):
#         if lst[y] < lst[x]:
#             k += 1
#
# for (l, r) in pair:
#     if (k - (r - l + 1) // 2) % 2 == 0:
#         print("even")
#     else:
#         print("odd")
#     k = k - (r - l + 1) // 2
#
# #######################################
# #############
# n = int(input())
# count = 0
# for i in range(1, n):
#     if (n-i)%i==0:
#         count+=1
#
# print(count)
# #######################################
# #############
# s1 = input()
# s1 = s1.split()
# n = int(s1[0])
# d = int(s1[1])
# s = input()
# count = 0
# pos = 1
# dk = d
# res = True
# while(pos!=n):
#     if dk==0:
#         res = False
#         break
#     if pos+dk<=n and s[pos+dk-1]=='1':
#         if dk==0:
#             res = False
#             break
#         pos+=dk
#         count+=1
#         dk = d
#     else:
#         dk-=1
#
# if res:
#     print(count)
# else:
#     print(-1)
# #######################################
# #############
# s1=  input().split()
# n = int(s1[0])
# m = int(s1[1])
# a = list(map(int, input().split()))
# b = list(map(int, input().split()))
# pos = 0
# cl = []
# smm = 0
# cl.append(0)
# for i in range(n):
#  smm+=a[i]
#  cl.append(smm)
# for x in b:
#  while(x>cl[pos]):
#   pos+=1
#  print('{} {}'.format(pos, x-cl[pos-1]))
# #######################################
# #############
# s = input()
# mx = 0
# for i in range(len(s)):
#     for j in range(i, len(s)+1):
#         if s[i:j]!=s[i:j][::-1]:
#             if j-i>mx:
#                 mx = j-i
#
# print(mx)
# #######################################
# #############
# s1 = list(map(int, input().split()))
# s2 = list(map(int, input().split()))
# hh, mm = s1[0], s1[1]
# h, d, c, n = s2[0], s2[1], s2[2], s2[3]
# res = 0
# if hh>=20:
#   if h%n==0:
#     res = h/n*c*0.8
#   else:
#     res = (h//n+1)*c*0.8
#   print(res)
# else:
#   x = 60-mm
#   y = 20-hh-1
#   res1 = h + (y*60 + x)*d
#   if res1%n==0:
#     res1 = res1/n*c*0.8
#   else:
#     res1 = (res1//n+1)*c*0.8
#
#   res2 = 0
#   if h%n==0:
#     res2 = h/n*c
#   else:
#     res2 = (h//n+1)*c
#   print(min(res1, res2))
# #######################################
# #############
# n=int(input())
# a=list(map(int,input().split()))
# m1=0
# m2=10000000
# for i in a:
#     if i<=500000 and i>m1:
#         m1=i
#     if i>500000 and i<m2:
#         m2=i
# print(max(m1-1,1000000-m2))
#
#
# #######################################
# #############
# n=int(input())
# a=list(map(int,input().split()))
# s=sum(a)/2
# now_s=0
# j=0
# for i in a:
#     j+=1
#     now_s+=i
#     if now_s>=s:
#         print(j)
#         break
#
# #######################################
# #############
# (n, a, b) = map(int, input().split())
#
# k = 0
# for x in range(1, n):
#     k = max(k, min(a // x, b // (n - x)))
#
# print(k)
#
# #######################################
# #############
# n = int(input())
#
# lst = [int(x) for x in input().split()]
#
# a = []
# for x in range(n - 1, -1, -1):
#     if not lst[x] in a:
#         a.append(lst[x])
#
# a.reverse()
# print(len(a))
# print(*a)
#
# #######################################
# #############
# x = int(input())
# s = input().split()
# hh = int(s[0])
# mm = int(s[1])
# res = 0
# k=0
# st = True
# if '7' in str(hh) or '7' in str(mm):
#     k=0
# else:
#     while(st):
#         if mm-x<0:
#             mm = 60-x+mm
#             if hh-1==-1:
#                 hh=23
#             else:
#                 hh-=1
#         else:
#             mm-=x
#         k+=1
#         if '7' in str(hh) or '7' in str(mm):
#             st = False
# print(k)
# #######################################
# #############
# from math import floor, sqrt
#
# n = int(input())
#
# lst = []
# for x in input().split():
#     lst.append(int(x))
#
# max_n = - 10 ** 6 - 1
# for x in lst:
#     if x >= 0:
#         p = floor(sqrt(x))
#         if p ** 2 != x:
#             max_n = max(max_n, x)
#     else:
#         max_n = max(max_n, x)
#
# print(max_n)
#
#
# #######################################
# #############
# s1 = input().split()
# s2 = input().split()
# a = int(s1[0])
# b = int(s1[1])
# x = int(s2[0])
# y = int(s2[1])
# z = int(s2[2])
# c1 = x*2+y
# c2 = z*3+y
# res = 0
# if a-c1<0:
#     res+=c1-a
# if b-c2<0:
#     res+=c2-b
#
# print(res)
#
# #######################################
# #############
# import fractions
# n = int(input())
# s = [int(x) for x in input().split()]
# s.sort(reverse=True)
# nod = abs(s[0] - s[1])
# for i in range(1, n):
#     delta = abs(s[i] - s[i - 1])
#     nod = fractions.gcd(nod, delta)
# max_i = s[0]
# min_i = s[-1]
# print((max_i - min_i) // nod + 1 - n)
# #######################################
# #############

# %%
cls.ast_encoder.subtree_network.state_dict()
# Out:
# OrderedDict([('weight_ih_l0',
#               tensor([[ 1.7906e-02,  1.6490e-02, -4.2106e-02,  ..., -5.6046e-02,
#                        -3.7342e-02, -5.7649e-02],
#                       [ 4.7855e-02, -3.9626e-02,  3.8272e-02,  ...,  5.5583e-02,
#                         7.3345e-02, -8.1834e-02],
#                       [-2.0350e-03, -5.6365e-02,  3.2535e-02,  ..., -5.9172e-02,
#                        -4.4430e-03,  1.5263e-02],
#                       ...,
#                       [ 6.1483e-02,  3.5354e-02, -3.4194e-02,  ..., -8.5102e-02,
#                        -7.0193e-03, -8.1718e-03],
#                       [ 5.9786e-02,  5.0703e-02,  2.4636e-02,  ..., -4.3646e-02,
#                        -5.4751e-02,  3.5124e-02],
#                       [ 2.3400e-02,  1.6515e-02,  5.8641e-04,  ..., -3.5725e-02,
#                         4.0353e-03,  1.7234e-02]])),
#              ('weight_hh_l0', tensor(1.00000e-02 *
#                      [[-2.8025, -0.1639, -7.7748,  ...,  7.5870,  6.3622, -4.3058],
#                       [ 7.1991,  2.6260, -8.6652,  ...,  2.2387,  0.2422, -5.1923],
#                       [ 7.4369,  8.5478,  2.2419,  ..., -2.7531,  5.9231,  3.0664],
#                       ...,
#                       [-6.9543,  8.5533, -3.1450,  ..., -0.5382,  5.5612,  4.9793],
#                       [ 4.5036, -7.9684, -8.0247,  ...,  4.2378,  2.0390,  8.5867],
#                       [ 0.1027, -4.4543, -3.2941,  ..., -5.5556,  1.4129,  5.0520]])),
#              ('bias_ih_l0',
#               tensor([-0.0592,  0.0124, -0.0477,  0.0696, -0.0715,  0.0449,  0.0641,
#                        0.0748, -0.0799, -0.0140,  0.0316, -0.0494, -0.0310,  0.0085,
#                       -0.0366, -0.0722,  0.0141,  0.0045, -0.0675, -0.0394, -0.0323,
#                        0.0457, -0.0420,  0.0218, -0.0682, -0.0666, -0.0171,  0.0158,
#                       -0.0037,  0.0354,  0.0039, -0.0228, -0.0212,  0.0097, -0.0128,
#                       -0.0460, -0.0613,  0.0264, -0.0548,  0.0208, -0.0724,  0.0636,
#                        0.0269,  0.0024,  0.0264,  0.0340, -0.0263, -0.0578, -0.0540,
#                       -0.0434, -0.0031, -0.0359, -0.0334,  0.0042,  0.0758,  0.0276,
#                       -0.0318, -0.0834, -0.0645, -0.0183,  0.0299,  0.0822,  0.0068,
#                        0.0525,  0.0824, -0.0081,  0.0425, -0.0075,  0.0339, -0.0700,
#                        0.0340,  0.0349,  0.0287, -0.0386, -0.0456, -0.0537,  0.0785,
#                       -0.0821, -0.0134,  0.0512,  0.0252,  0.0073, -0.0656, -0.0225,
#                       -0.0134, -0.0094, -0.0385, -0.0686, -0.0255,  0.0003, -0.0051,
#                       -0.0515,  0.0114, -0.0345, -0.0525, -0.0496, -0.0748,  0.0663,
#                       -0.0841,  0.0197,  0.0386,  0.0674, -0.0155,  0.0119, -0.0582,
#                        0.0465, -0.0325,  0.0673, -0.0242, -0.0328, -0.0336,  0.0580,
#                        0.0702, -0.0070,  0.0827,  0.0012, -0.0064,  0.0407,  0.0545,
#                        0.0179,  0.0633,  0.0413, -0.0151, -0.0637, -0.0457, -0.0188,
#                        0.0761,  0.0836,  0.0049,  0.0125,  0.0429,  0.0713,  0.0497,
#                       -0.0222,  0.0049,  0.0750,  0.0707,  0.0852,  0.0238,  0.0182,
#                        0.0325, -0.0457,  0.0899,  0.0827,  0.0185,  0.0531, -0.0305,
#                        0.0165,  0.0455,  0.0553,  0.0365,  0.0664, -0.0145,  0.0499,
#                        0.0393,  0.0118, -0.0260,  0.0261,  0.0132,  0.0638, -0.0005,
#                       -0.0563,  0.0449,  0.0485,  0.0692, -0.0140, -0.0640,  0.0480,
#                       -0.0788, -0.0295,  0.0429, -0.0064,  0.0431, -0.0747,  0.0167,
#                       -0.0840,  0.0484, -0.0487, -0.0320,  0.0258, -0.0828,  0.0748,
#                       -0.0733,  0.0508,  0.0700, -0.0221, -0.0346,  0.0156, -0.0755,
#                        0.0327, -0.0106, -0.0788, -0.0362,  0.0145, -0.0532, -0.0000,
#                        0.0052, -0.0538, -0.0157,  0.0471,  0.0329,  0.0629, -0.0619,
#                        0.0399,  0.0595,  0.0813, -0.0642,  0.0075,  0.0415,  0.0749,
#                        0.0482, -0.0133, -0.0635,  0.0348, -0.0414,  0.0311,  0.0859,
#                        0.0154,  0.0359,  0.0524,  0.0053,  0.0342, -0.0753,  0.0551,
#                       -0.0415,  0.0611,  0.0229, -0.0236, -0.0625,  0.0528, -0.0768,
#                       -0.0311, -0.0712,  0.0068,  0.0323, -0.0838, -0.0186, -0.0203,
#                       -0.0704, -0.0521,  0.0378,  0.0668,  0.0174,  0.0100,  0.0356,
#                        0.0708,  0.0048,  0.0101, -0.0436,  0.0172,  0.0610, -0.0500,
#                       -0.0455, -0.0542, -0.0501, -0.0712, -0.0546,  0.0615, -0.0231,
#                       -0.0595, -0.0521,  0.0105,  0.0703,  0.0170,  0.0442, -0.0431,
#                       -0.0549,  0.0098, -0.0368, -0.0670,  0.0316, -0.0413, -0.0125,
#                       -0.0102,  0.0777,  0.0352,  0.0524,  0.0288, -0.0290, -0.0148,
#                        0.0082,  0.0815, -0.0426, -0.0135, -0.0047,  0.0002, -0.0338,
#                       -0.0678,  0.0325, -0.0500,  0.0564,  0.0732, -0.0569,  0.0490,
#                        0.0522, -0.0508, -0.0873, -0.1099,  0.0215, -0.0107, -0.0343,
#                        0.0094,  0.0138, -0.0181,  0.0836, -0.0014,  0.0349,  0.0100,
#                        0.0403, -0.0661,  0.0648, -0.0006, -0.0856,  0.0664, -0.0038,
#                       -0.0786, -0.0606, -0.0460, -0.0672, -0.0450,  0.0389,  0.0117,
#                        0.0477,  0.0581, -0.0918,  0.0434, -0.0852,  0.0580,  0.0031,
#                        0.0236,  0.0573, -0.0301, -0.0433, -0.0558, -0.0465, -0.0310,
#                        0.0228,  0.0509, -0.0221, -0.0687,  0.0653,  0.0402,  0.0951,
#                       -0.0685,  0.0167,  0.0096, -0.0343,  0.0797,  0.0239,  0.0554,
#                        0.0251, -0.0381, -0.0180,  0.0075,  0.1078, -0.0510,  0.0048,
#                        0.0099, -0.0317,  0.0894,  0.0193, -0.0595,  0.0533, -0.0653,
#                       -0.0370, -0.0170, -0.0582,  0.0501, -0.0897,  0.0923,  0.0089,
#                        0.0733,  0.0343,  0.0106, -0.0094, -0.0078,  0.0015,  0.0057,
#                        0.0830, -0.0441,  0.0510,  0.0079, -0.0236,  0.1031,  0.0638,
#                       -0.0378, -0.0756,  0.0762,  0.0106, -0.0235, -0.0389,  0.0451,
#                       -0.0757,  0.0054, -0.0940, -0.0028,  0.0860, -0.0509, -0.0645,
#                       -0.0792, -0.0602, -0.0803,  0.0807,  0.0280, -0.0799,  0.0141,
#                        0.0546, -0.0606, -0.0039, -0.0506, -0.0712,  0.0242, -0.0548,
#                        0.0297,  0.0290, -0.0825, -0.0064,  0.0734, -0.0172, -0.0394,
#                        0.0781, -0.0272, -0.0833, -0.0808,  0.0361, -0.0073, -0.0771,
#                        0.0382, -0.0449, -0.0581,  0.0179,  0.0393, -0.0788,  0.0133,
#                        0.0032,  0.0013, -0.0462,  0.0820,  0.0746, -0.0813,  0.0030,
#                       -0.0222,  0.0695, -0.0167,  0.0096, -0.0568, -0.0740,  0.0732,
#                       -0.0055,  0.0214,  0.0469, -0.0630, -0.0248, -0.0164, -0.0247,
#                        0.0181,  0.0382,  0.0172,  0.0738, -0.0828,  0.0642,  0.0249,
#                       -0.0588,  0.0142,  0.0825, -0.0525,  0.0108, -0.0382, -0.0471,
#                       -0.0738, -0.0542, -0.0145,  0.0289,  0.0362,  0.0504, -0.0569,
#                        0.0077,  0.0587, -0.0352,  0.0880,  0.0129,  0.0308, -0.0455,
#                        0.0581, -0.0381,  0.0198, -0.0069,  0.0425,  0.0578,  0.0150,
#                        0.0833, -0.0816,  0.0802,  0.0534,  0.0623,  0.0449,  0.0558,
#                        0.0870, -0.0516, -0.0133, -0.0687,  0.0249, -0.0103,  0.0752,
#                       -0.0402, -0.0308, -0.0780,  0.0035, -0.0373,  0.0831, -0.0109,
#                       -0.0723, -0.0127, -0.0773, -0.0662,  0.0127,  0.0376,  0.0433,
#                       -0.0674, -0.0386,  0.0613,  0.0512, -0.0249, -0.0059,  0.0674,
#                        0.0403,  0.0754, -0.0494])),
#              ('bias_hh_l0',
#               tensor([-0.0510,  0.0416,  0.0215,  0.0205,  0.0535, -0.0087, -0.0080,
#                        0.0735, -0.0331, -0.0872,  0.0407, -0.0223,  0.0740, -0.0660,
#                        0.0398,  0.0217,  0.0247,  0.0841, -0.0402, -0.0516, -0.0178,
#                        0.0091,  0.0448, -0.0751,  0.0359,  0.0010,  0.0700, -0.0338,
#                       -0.0157,  0.0178, -0.0735, -0.0391, -0.0800, -0.0391,  0.0617,
#                        0.0266, -0.0280,  0.0694, -0.0113,  0.0019, -0.0056,  0.0435,
#                        0.0047, -0.0474, -0.0276,  0.0495, -0.0530, -0.0156,  0.0551,
#                        0.0760, -0.0509,  0.0711,  0.0572,  0.0064,  0.0083,  0.0524,
#                       -0.0627, -0.0585,  0.0764, -0.0207,  0.0026,  0.0766,  0.0083,
#                        0.0476,  0.0346,  0.0560, -0.0752,  0.0073, -0.0229, -0.0003,
#                        0.0446, -0.0585, -0.0091, -0.0365, -0.0419, -0.0062, -0.0839,
#                       -0.0375, -0.0811,  0.0186,  0.0194,  0.0570, -0.0085, -0.0499,
#                        0.0048,  0.0456,  0.0352,  0.0476,  0.0067, -0.0658,  0.0240,
#                       -0.0308,  0.0871,  0.0548,  0.0138,  0.0688,  0.0436,  0.0648,
#                       -0.0385, -0.0597, -0.0574, -0.0152,  0.0203,  0.0763,  0.0231,
#                        0.0804,  0.0718, -0.0763, -0.0276,  0.0471, -0.0112,  0.0253,
#                        0.0506, -0.0080, -0.0119,  0.0846, -0.0650,  0.0457,  0.0135,
#                       -0.0480, -0.0593,  0.0764,  0.0253,  0.0256, -0.0229, -0.0383,
#                        0.0074, -0.0798, -0.0615,  0.0375, -0.0174, -0.0376, -0.0215,
#                       -0.0338,  0.0838, -0.0167, -0.0665, -0.0258, -0.0344,  0.0609,
#                        0.0690,  0.0536, -0.0432,  0.0070,  0.0377,  0.0831, -0.0309,
#                       -0.0017,  0.0058, -0.0653, -0.0383,  0.0750,  0.0540,  0.0758,
#                        0.0015,  0.0253,  0.0251,  0.0158, -0.0633,  0.0493,  0.0370,
#                       -0.0335,  0.0795, -0.0290, -0.0118, -0.0522, -0.0511,  0.0270,
#                        0.0572,  0.0837,  0.0274,  0.0583, -0.0543, -0.0231, -0.0702,
#                        0.0392,  0.0593, -0.0012, -0.0164, -0.0258,  0.0040,  0.0245,
#                        0.0867, -0.0294, -0.0221,  0.0499,  0.0910,  0.0488,  0.0603,
#                       -0.0203, -0.0285,  0.0725,  0.0738, -0.0347,  0.0578,  0.0061,
#                        0.0103,  0.0652, -0.0685,  0.0135, -0.0384, -0.0144,  0.0105,
#                        0.0463, -0.0614, -0.0322,  0.0128,  0.0092, -0.0107,  0.0533,
#                        0.0779,  0.0716, -0.0091, -0.0018,  0.0012, -0.0195, -0.0541,
#                       -0.0602, -0.0256,  0.0609, -0.0632, -0.0743, -0.0178,  0.0824,
#                        0.0821,  0.0326,  0.0298,  0.0521,  0.0170, -0.0388, -0.0157,
#                        0.0400,  0.0694, -0.0400, -0.0210,  0.0633,  0.0593, -0.0586,
#                        0.0687, -0.0005,  0.0220,  0.0375, -0.0171, -0.0531,  0.0025,
#                        0.0202,  0.0185, -0.0588, -0.0549,  0.0663, -0.0563,  0.0466,
#                        0.0466, -0.0375,  0.0277,  0.0557, -0.0141, -0.0756,  0.0308,
#                        0.0347, -0.0436,  0.0480, -0.0595,  0.0447,  0.0803, -0.0679,
#                       -0.0894, -0.0588, -0.0169, -0.0562, -0.0367, -0.0143, -0.0381,
#                        0.0707,  0.0724,  0.0617,  0.0689,  0.0749,  0.0001, -0.0494,
#                       -0.0274, -0.0556,  0.0944, -0.0501,  0.0249, -0.0358,  0.0443,
#                       -0.0145,  0.0666, -0.0896,  0.0502,  0.0306, -0.0375,  0.0233,
#                        0.0681, -0.0270,  0.0746, -0.0946, -0.0225, -0.0971,  0.0716,
#                        0.0823,  0.0996,  0.1046,  0.1214,  0.0923,  0.0449,  0.0171,
#                       -0.0043, -0.1109,  0.0867, -0.0881, -0.0074,  0.0032, -0.1064,
#                       -0.0633,  0.0770, -0.0804, -0.0734, -0.0630,  0.0487, -0.0561,
#                        0.0821,  0.0201,  0.0209,  0.0289, -0.0828, -0.0539, -0.0938,
#                        0.0715, -0.0241, -0.0614, -0.0452, -0.0894, -0.0843, -0.0818,
#                       -0.0447,  0.0474,  0.0404, -0.0074,  0.1023, -0.0314, -0.0687,
#                        0.0554, -0.0590, -0.0345,  0.0459,  0.0133, -0.0784, -0.0140,
#                       -0.0337, -0.0499, -0.0271, -0.0815,  0.0530,  0.0972,  0.0813,
#                        0.0553,  0.0432, -0.0319, -0.0375,  0.0824,  0.0098, -0.0153,
#                        0.0130, -0.0337, -0.0512,  0.0253, -0.1065,  0.0300, -0.0031,
#                        0.0612, -0.0102,  0.0647,  0.0414, -0.0210,  0.1160,  0.0766,
#                        0.0672,  0.0618,  0.0463, -0.0276,  0.0046, -0.0269, -0.0750,
#                       -0.0674, -0.0348,  0.0405,  0.0402,  0.0263, -0.0664,  0.0937,
#                       -0.0246, -0.0769,  0.0512,  0.0333, -0.0830, -0.0828,  0.0315,
#                       -0.0731,  0.0809, -0.0161, -0.0793,  0.0004,  0.0811,  0.0135,
#                       -0.0619,  0.0451,  0.0633, -0.0170,  0.0570, -0.0120,  0.0295,
#                       -0.0028,  0.0252,  0.0755, -0.0076, -0.0131,  0.0609, -0.0625,
#                        0.0226,  0.0398, -0.0285, -0.0191,  0.0671, -0.0161,  0.0626,
#                       -0.0190,  0.0522,  0.0447, -0.0446,  0.0047,  0.0718,  0.0415,
#                       -0.0839, -0.0334,  0.0288,  0.0541, -0.0176, -0.0050,  0.0431,
#                        0.0054, -0.0287,  0.0167,  0.0577,  0.0549,  0.0581,  0.0626,
#                        0.0017,  0.0616,  0.0493, -0.0505, -0.0225,  0.0401,  0.0395,
#                        0.0541, -0.0184,  0.0515, -0.0713,  0.0173,  0.0370,  0.0730,
#                       -0.0732, -0.0488, -0.0394, -0.0764, -0.0760,  0.0726,  0.0793,
#                       -0.0432, -0.0747,  0.0743,  0.0182, -0.0416,  0.0297, -0.0799,
#                        0.0735, -0.0413,  0.0362, -0.0602,  0.0017, -0.0103,  0.0077,
#                       -0.0318,  0.0228, -0.0169,  0.0382, -0.0060, -0.0458, -0.0628,
#                        0.0794,  0.0016, -0.0409,  0.0088, -0.0116,  0.0870, -0.0002,
#                       -0.0684, -0.0783,  0.0381, -0.0611,  0.0301,  0.0824,  0.0520,
#                        0.0269,  0.0536, -0.0236, -0.0243, -0.0618,  0.0113,  0.0097,
#                        0.0147, -0.0052, -0.0604,  0.0285,  0.0192, -0.0586, -0.0414,
#                        0.0291, -0.0522, -0.0419, -0.0517, -0.0826, -0.0248, -0.0299,
#                       -0.0682,  0.0337, -0.0105]))])
